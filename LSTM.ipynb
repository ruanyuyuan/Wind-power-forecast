# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('wind2019.csv')
df.head(100)
# Out:
#                      时间  测风塔10m风速(m/s)  测风塔30m风速(m/s)  测风塔50m风速(m/s)  \
# 0   2019-01-01 00:00:00          0.223          0.000          0.000
# 1   2019-01-01 00:15:00          0.000          0.000          0.000
# 2   2019-01-01 00:30:00          0.000          0.000          0.000
# 3   2019-01-01 00:45:00          0.818          0.000          0.000
# 4   2019-01-01 01:00:00          1.041          0.000          0.297
# ..                  ...            ...            ...            ...
# 95  2019-01-01 23:45:00          3.155          3.461          2.798
# 96  2019-01-02 00:00:00          2.543          2.798          2.033
# 97  2019-01-02 00:15:00          1.829          2.747          2.135
# 98  2019-01-02 00:30:00          2.645          2.033          2.390
# 99  2019-01-02 00:45:00          3.308          2.135          2.849
#
#     测风塔10m风向(°)  测风塔30m风向(°)  测风塔50m风向(°)   温度(°)  气压(hPa)   湿度(%)  实际发电功率（mw）
# 0       166.816      177.355        6.224 -13.154  898.710  53.497    0.979591
# 1       166.832      177.356        6.526 -13.864  898.621  55.999    1.150984
# 2       166.859      177.353       28.936 -14.461  898.497  57.747    1.066162
# 3       166.894      177.344       29.212 -13.066  898.329  54.162    0.923717
# 4       166.892      177.352       29.378 -12.823  898.356  52.807    0.813552
# ..          ...          ...          ...     ...      ...     ...         ...
# 95      169.334      161.863        6.641 -11.289  892.893  51.098    0.954867
# 96      169.808      167.790        6.497 -11.851  892.889  52.669    1.301044
# 97      183.806      178.947        6.696 -11.293  892.827  51.019    1.229518
# 98      160.364      186.116        6.881 -12.165  892.663  53.786    1.001882
# 99      157.742      187.094        6.902 -13.097  892.566  57.127    0.953660
#
# [100 rows x 11 columns]

# %%
idx_df = df.set_index(['时间'])
idx_df.describe().T  #用于计算数值列的描述性统计信息，如计数、均值、标准差、最小值、最大值等
# Out:
#                  count        mean        std        min        25%  \
# 测风塔10m风速(m/s)  35040.0    4.818662   3.516523    0.00000    2.36400
# 测风塔30m风速(m/s)  35040.0    5.347264   3.836181    0.00000    2.62000
# 测风塔50m风速(m/s)  35040.0    5.773827   4.053695    0.00000    2.77200
# 测风塔10m风向(°)    35040.0  156.220382  86.821714    0.00000   82.25375
# 测风塔30m风向(°)    35040.0  158.638939  89.835426    0.00000   79.70725
# 测风塔50m风向(°)    35040.0   11.587642  16.812424    0.00000    5.85200
# 温度(°)          35040.0   11.324763  14.027540  -18.66200   -1.57650
# 气压(hPa)        35040.0  888.509122   5.793348  874.58400  883.63200
# 湿度(%)          35040.0   33.592505  20.761404    2.50600   16.64700
# 实际发电功率（mw）     35040.0   53.907954  56.733980    0.25836    3.52621
#
#                       50%        75%        max
# 测风塔10m风速(m/s)    3.869000    6.60200   19.24600
# 测风塔30m风速(m/s)    4.481000    7.31200   21.05600
# 测风塔50m风速(m/s)    4.660000    8.00000   22.38200
# 测风塔10m风向(°)    137.966500  230.50950  359.94600
# 测风塔30m风向(°)    137.621000  239.89550  360.00000
# 测风塔50m风向(°)      6.392000   11.53925  355.82300
# 温度(°)           13.105500   23.04225   40.13100
# 气压(hPa)        888.638000  892.70800  905.30700
# 湿度(%)           28.122000   47.54425   94.92100
# 实际发电功率（mw）      29.037047   99.74149  202.22884

# %%
idx_df.head(10)
# Out:
#                      测风塔10m风速(m/s)  测风塔30m风速(m/s)  测风塔50m风速(m/s)  测风塔10m风向(°)  \
# 时间
# 2019-01-01 00:00:00          0.223          0.000          0.000      166.816
# 2019-01-01 00:15:00          0.000          0.000          0.000      166.832
# 2019-01-01 00:30:00          0.000          0.000          0.000      166.859
# 2019-01-01 00:45:00          0.818          0.000          0.000      166.894
# 2019-01-01 01:00:00          1.041          0.000          0.297      166.892
# 2019-01-01 01:15:00          1.676          0.520          1.319      166.916
# 2019-01-01 01:30:00          2.645          1.472          2.033      166.872
# 2019-01-01 01:45:00          1.880          2.747          2.339      176.703
# 2019-01-01 02:00:00          1.676          2.543          2.543      176.739
# 2019-01-01 02:15:00          0.000          0.149          2.798      176.704
#
#                      测风塔30m风向(°)  测风塔50m风向(°)   温度(°)  气压(hPa)   湿度(%)  \
# 时间
# 2019-01-01 00:00:00      177.355        6.224 -13.154  898.710  53.497
# 2019-01-01 00:15:00      177.356        6.526 -13.864  898.621  55.999
# 2019-01-01 00:30:00      177.353       28.936 -14.461  898.497  57.747
# 2019-01-01 00:45:00      177.344       29.212 -13.066  898.329  54.162
# 2019-01-01 01:00:00      177.352       29.378 -12.823  898.356  52.807
# 2019-01-01 01:15:00      177.356       12.255 -12.793  898.196  51.031
# 2019-01-01 01:30:00      177.280        6.489 -13.671  898.076  53.597
# 2019-01-01 01:45:00      192.212        8.162 -13.905  897.939  54.602
# 2019-01-01 02:00:00      206.758        9.875 -13.270  897.775  53.981
# 2019-01-01 02:15:00      206.675        9.206 -13.598  897.779  54.478
#
#                      实际发电功率（mw）
# 时间
# 2019-01-01 00:00:00    0.979591
# 2019-01-01 00:15:00    1.150984
# 2019-01-01 00:30:00    1.066162
# 2019-01-01 00:45:00    0.923717
# 2019-01-01 01:00:00    0.813552
# 2019-01-01 01:15:00    1.385237
# 2019-01-01 01:30:00    5.187509
# 2019-01-01 01:45:00    8.714045
# 2019-01-01 02:00:00   11.367244
# 2019-01-01 02:15:00   11.250483

# %%
idx_df.isnull().sum()#DataFrame 中每列的缺失值数量。通过这个操作，您可以了解每列中缺失值的分布情况，并进行进一步的数据清洗或处理。
# Out:
# 测风塔10m风速(m/s)    0
# 测风塔30m风速(m/s)    0
# 测风塔50m风速(m/s)    0
# 测风塔10m风向(°)      0
# 测风塔30m风向(°)      0
# 测风塔50m风向(°)      0
# 温度(°)            0
# 气压(hPa)          0
# 湿度(%)            0
# 实际发电功率（mw）       0
# dtype: int64

# %%
import matplotlib.font_manager as font_manager

# 指定中文字体文件路径
font_path = 'C:/Windows/Fonts/simsun.ttc'

# 加载中文字体
prop = font_manager.FontProperties(fname=font_path)

# 设置中文字体为默认字体
plt.rcParams['font.family'] = prop.get_name()
fig,ax = plt.subplots(figsize = (10,10))
sns.heatmap(idx_df.corr(),ax=ax,annot = True)
# Out:
# D:\JetBrains\ANACONDA\envs\py37\lib\site-packages\seaborn\utils.py:80: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.draw()
# <AxesSubplot:>
# D:\JetBrains\ANACONDA\envs\py37\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   func(*args, **kwargs)
# D:\JetBrains\ANACONDA\envs\py37\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
idx_df.corr()['实际发电功率（mw）'].sort_values(ascending=False)
# Out:
# 实际发电功率（mw）       1.000000
# 测风塔50m风速(m/s)    0.784718
# 测风塔30m风速(m/s)    0.761795
# 测风塔10m风速(m/s)    0.746070
# 温度(°)            0.132965
# 气压(hPa)         -0.127836
# 湿度(%)           -0.136031
# 测风塔50m风向(°)     -0.190069
# 测风塔10m风向(°)     -0.344054
# 测风塔30m风向(°)     -0.369254
# Name: 实际发电功率（mw）, dtype: float64

# %%
idx_df.shape
# Out:
# (35040, 10)

# %%
idx_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 35040 entries, 2019-01-01 00:00:00 to 2019-12-31 23:45:00
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   测风塔10m风速(m/s)  35040 non-null  float64
#  1   测风塔30m风速(m/s)  35040 non-null  float64
#  2   测风塔50m风速(m/s)  35040 non-null  float64
#  3   测风塔10m风向(°)    35040 non-null  float64
#  4   测风塔30m风向(°)    35040 non-null  float64
#  5   测风塔50m风向(°)    35040 non-null  float64
#  6   温度(°)          35040 non-null  float64
#  7   气压(hPa)        35040 non-null  float64
#  8   湿度(%)          35040 non-null  float64
#  9   实际发电功率（mw）     35040 non-null  float64
# dtypes: float64(10)
# memory usage: 2.9+ MB

# %%
df2 = idx_df.drop(['测风塔10m风向(°)','测风塔30m风向(°)'],axis=1)

x = df2.iloc[:,:].values #转化成numpy类型
print(x)
print(x.shape)
# Out:
# [[2.23000000e-01 0.00000000e+00 0.00000000e+00 ... 8.98710000e+02
#   5.34970000e+01 9.79591000e-01]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 8.98621000e+02
#   5.59990000e+01 1.15098400e+00]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 8.98497000e+02
#   5.77470000e+01 1.06616200e+00]
#  ...
#  [7.46400000e+00 8.15300000e+00 8.76500000e+00 ... 8.88383000e+02
#   4.11360000e+01 1.34717210e+02]
#  [5.70500000e+00 7.15800000e+00 8.07600000e+00 ... 8.88389000e+02
#   4.12880000e+01 1.26557410e+02]
#  [7.15800000e+00 8.00000000e+00 9.68300000e+00 ... 8.88469000e+02
#   4.01230000e+01 1.09673615e+02]]
# (35040, 8)

# %%
from sklearn.preprocessing import MinMaxScaler
x_sc = MinMaxScaler()
x = x_sc.fit_transform(x)
# print(x.shape)
# print(x)

# 获取归一化时用的最大值和最小值
max_values = x_sc.data_max_
min_values = x_sc.data_min_

# 打印每个特征的最大值和最小值
for feature, max_val, min_val in zip(range(len(max_values)), max_values, min_values):
    print(f"Feature {feature}: Max Value = {max_val}, Min Value = {min_val}")
# Out:
# Feature 0: Max Value = 19.246, Min Value = 0.0
# Feature 1: Max Value = 21.055999999999997, Min Value = 0.0
# Feature 2: Max Value = 22.381999999999998, Min Value = 0.0
# Feature 3: Max Value = 355.82300000000004, Min Value = 0.0
# Feature 4: Max Value = 40.131, Min Value = -18.662
# Feature 5: Max Value = 905.307, Min Value = 874.584
# Feature 6: Max Value = 94.921, Min Value = 2.506
# Feature 7: Max Value = 202.22884, Min Value = 0.25836

# %%
# 滑动窗口截取数据

def multivariate_data(dataset, target, start_index, end_index, history_size,
                      target_size, step, single_step=False):
    data = []
    labels = []

    start_index = start_index + history_size
    
    if end_index is None:
        end_index = len(dataset) - target_size

    for i in range(start_index, end_index):
        indices = range(i-history_size, i, step) # step表示滑动步长
        data.append(dataset[indices])

        if single_step:
            labels.append(target[i+target_size])
        else:
            labels.append(target[i:i+target_size])

    return np.array(data), np.array(labels)

# %%
past_history = 8  #2小时观测值
future_target = 0  #下一个时间点的功率值
STEP = 1

x_train_single, y_train_single = multivariate_data(x, x[:, -1], 0,
                                                   24528, past_history,
                                                   future_target, STEP,
                                                   single_step=True)
x_val_single, y_val_single = multivariate_data(x, x[:, -1],
                                              24528 , 31536, past_history,
                                               future_target, STEP,
                                               single_step=True)
x_test_single, y_test_single = multivariate_data(x, x[:, -1],
                                               31536, None, past_history,
                                               future_target, STEP,
                                               single_step=True)
print(y_train_single.shape)
print(y_train_single)
# print(x_val_single.shape)
# print(x_test_single.shape)
# print(x_train_single)
# print(y_test_single.shape)
# Out:
# (24520,)
# [0.05500251 0.0544244  0.04823228 ... 0.0103412  0.0256572  0.02965432]

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import LSTM,Bidirectional,GRU,Input, Conv1D,Multiply,Flatten,MaxPooling1D,concatenate,GlobalAveragePooling1D,Reshape
from tensorflow.keras.layers import Dense, Activation, BatchNormalization, Dropout,Permute,Lambda,RepeatVector
from tensorflow.keras import regularizers
from tensorflow.keras.optimizers import RMSprop, Adam, SGD
import tensorflow.keras.backend as K
from tensorflow.keras.models import Model
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.callbacks import ReduceLROnPlateau,ModelCheckpoint

# %%
#模型LSTM双层的
model = tf.keras.Sequential()

# 添加第一个LSTM层，指定神经元数量、返回序列以及输入形状
model.add(LSTM(units=32, return_sequences=True, kernel_regularizer=tf.keras.regularizers.l2(0.01), input_shape=(8, 8)))
model.add(Activation('relu'))
# 添加第二个LSTM层，指定神经元数量和返回序列
model.add(LSTM(units=16, kernel_regularizer=tf.keras.regularizers.l2(0.01),return_sequences=False))

# # 添加第三个GRU层，指定神经元数量和返回序列
# model.add(GRU(32, return_sequences=False))
model.add(Dropout(0.5))  # 添加Dropout层，指定丢弃率
model.add(Dense(units=1))  # 添加全连接层，指定输出单元数量为4
model.add(Activation('relu'))
adam = Adam(learning_rate=0.001)
model.compile(optimizer=adam, loss='mean_squared_error',metrics = [tf.keras.metrics.RootMeanSquaredError()])#metrics = [tf.keras.metrics.RootMeanSquaredError()
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_2 (LSTM)                (None, 8, 32)             5248
# _________________________________________________________________
# activation_2 (Activation)    (None, 8, 32)             0
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 16)                3136
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 17
# _________________________________________________________________
# activation_3 (Activation)    (None, 1)                 0
# =================================================================
# Total params: 8,401
# Trainable params: 8,401
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(x_train_single, y_train_single, epochs=100, batch_size=64,  validation_data=(x_val_single, y_val_single),verbose=1
                    )
# Out:
# Epoch 1/100
# 384/384 [==============================] - 4s 6ms/step - loss: 0.3105 - root_mean_squared_error: 0.2181 - val_loss: 0.0212 - val_root_mean_squared_error: 0.1071
# Epoch 2/100
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0277 - root_mean_squared_error: 0.1423 - val_loss: 0.0135 - val_root_mean_squared_error: 0.0910
# Epoch 3/100
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0204 - root_mean_squared_error: 0.1244 - val_loss: 0.0115 - val_root_mean_squared_error: 0.0844
# Epoch 4/100
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0180 - root_mean_squared_error: 0.1168 - val_loss: 0.0138 - val_root_mean_squared_error: 0.0998
# Epoch 5/100
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0163 - root_mean_squared_error: 0.1120 - val_loss: 0.0095 - val_root_mean_squared_error: 0.0767
# Epoch 6/100
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0157 - root_mean_squared_error: 0.1100 - val_loss: 0.0092 - val_root_mean_squared_error: 0.0757
# Epoch 7/100
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0153 - root_mean_squared_error: 0.1084 - val_loss: 0.0114 - val_root_mean_squared_error: 0.0895
# Epoch 8/100
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0144 - root_mean_squared_error: 0.1051 - val_loss: 0.0087 - val_root_mean_squared_error: 0.0741
# Epoch 9/100
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0140 - root_mean_squared_error: 0.1037 - val_loss: 0.0081 - val_root_mean_squared_error: 0.0702
# Epoch 10/100
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0137 - root_mean_squared_error: 0.1027 - val_loss: 0.0081 - val_root_mean_squared_error: 0.0714
# Epoch 11/100
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0131 - root_mean_squared_error: 0.1008 - val_loss: 0.0085 - val_root_mean_squared_error: 0.0751
# Epoch 12/100
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0131 - root_mean_squared_error: 0.1012 - val_loss: 0.0077 - val_root_mean_squared_error: 0.0713
# Epoch 13/100
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0123 - root_mean_squared_error: 0.0981 - val_loss: 0.0072 - val_root_mean_squared_error: 0.0678
# Epoch 14/100
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0121 - root_mean_squared_error: 0.0979 - val_loss: 0.0069 - val_root_mean_squared_error: 0.0658
# Epoch 15/100
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0124 - root_mean_squared_error: 0.0989 - val_loss: 0.0066 - val_root_mean_squared_error: 0.0635
# Epoch 16/100
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0120 - root_mean_squared_error: 0.0974 - val_loss: 0.0073 - val_root_mean_squared_error: 0.0701
# Epoch 17/100
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0115 - root_mean_squared_error: 0.0950 - val_loss: 0.0064 - val_root_mean_squared_error: 0.0631
# Epoch 18/100
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0112 - root_mean_squared_error: 0.0939 - val_loss: 0.0064 - val_root_mean_squared_error: 0.0641
# Epoch 19/100
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0108 - root_mean_squared_error: 0.0920 - val_loss: 0.0062 - val_root_mean_squared_error: 0.0619
# Epoch 20/100
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0108 - root_mean_squared_error: 0.0920 - val_loss: 0.0057 - val_root_mean_squared_error: 0.0583
# Epoch 21/100
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0103 - root_mean_squared_error: 0.0895 - val_loss: 0.0062 - val_root_mean_squared_error: 0.0626
# Epoch 22/100
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0107 - root_mean_squared_error: 0.0916 - val_loss: 0.0060 - val_root_mean_squared_error: 0.0619
# Epoch 23/100
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0103 - root_mean_squared_error: 0.0903 - val_loss: 0.0055 - val_root_mean_squared_error: 0.0584
# Epoch 24/100
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0099 - root_mean_squared_error: 0.0882 - val_loss: 0.0061 - val_root_mean_squared_error: 0.0633
# Epoch 25/100
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0100 - root_mean_squared_error: 0.0888 - val_loss: 0.0055 - val_root_mean_squared_error: 0.0588
# Epoch 26/100
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0101 - root_mean_squared_error: 0.0900 - val_loss: 0.0059 - val_root_mean_squared_error: 0.0613
# Epoch 27/100
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0098 - root_mean_squared_error: 0.0876 - val_loss: 0.0053 - val_root_mean_squared_error: 0.0568
# Epoch 28/100
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0096 - root_mean_squared_error: 0.0868 - val_loss: 0.0052 - val_root_mean_squared_error: 0.0550
# Epoch 29/100
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0095 - root_mean_squared_error: 0.0859 - val_loss: 0.0055 - val_root_mean_squared_error: 0.0586
# Epoch 30/100
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0096 - root_mean_squared_error: 0.0866 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0510
# Epoch 31/100
# 384/384 [==============================] - 3s 7ms/step - loss: 0.0093 - root_mean_squared_error: 0.0849 - val_loss: 0.0049 - val_root_mean_squared_error: 0.0534
# Epoch 32/100
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0091 - root_mean_squared_error: 0.0841 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0546
# Epoch 33/100
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0089 - root_mean_squared_error: 0.0829 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0525
# Epoch 34/100
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0088 - root_mean_squared_error: 0.0821 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0506
# Epoch 35/100
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0088 - root_mean_squared_error: 0.0825 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0534
# Epoch 36/100
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0087 - root_mean_squared_error: 0.0819 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0527
# Epoch 37/100
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0085 - root_mean_squared_error: 0.0809 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0527
# Epoch 38/100
# 384/384 [==============================] - 3s 7ms/step - loss: 0.0087 - root_mean_squared_error: 0.0818 - val_loss: 0.0051 - val_root_mean_squared_error: 0.0565
# Epoch 39/100
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0086 - root_mean_squared_error: 0.0818 - val_loss: 0.0049 - val_root_mean_squared_error: 0.0556
# Epoch 40/100
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0083 - root_mean_squared_error: 0.0804 - val_loss: 0.0049 - val_root_mean_squared_error: 0.0553
# Epoch 41/100
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0083 - root_mean_squared_error: 0.0804 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0535
# Epoch 42/100
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0082 - root_mean_squared_error: 0.0798 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0497
# Epoch 43/100
# 384/384 [==============================] - 3s 7ms/step - loss: 0.0082 - root_mean_squared_error: 0.0799 - val_loss: 0.0065 - val_root_mean_squared_error: 0.0685
# Epoch 44/100
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0083 - root_mean_squared_error: 0.0804 - val_loss: 0.0040 - val_root_mean_squared_error: 0.0471
# Epoch 45/100
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0081 - root_mean_squared_error: 0.0795 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0518
# Epoch 46/100
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0082 - root_mean_squared_error: 0.0803 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0486
# Epoch 47/100
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0078 - root_mean_squared_error: 0.0772 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0526
# Epoch 48/100
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0079 - root_mean_squared_error: 0.0782 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0529
# Epoch 49/100
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0079 - root_mean_squared_error: 0.0783 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0544
# Epoch 50/100
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0076 - root_mean_squared_error: 0.0762 - val_loss: 0.0056 - val_root_mean_squared_error: 0.0620
# Epoch 51/100
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0076 - root_mean_squared_error: 0.0767 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0503
# Epoch 52/100
# 384/384 [==============================] - 14s 35ms/step - loss: 0.0080 - root_mean_squared_error: 0.0790 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0462
# Epoch 53/100
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0079 - root_mean_squared_error: 0.0786 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0533
# Epoch 54/100
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0075 - root_mean_squared_error: 0.0766 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0489
# Epoch 55/100
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0078 - root_mean_squared_error: 0.0781 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0460
# Epoch 56/100
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0076 - root_mean_squared_error: 0.0767 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0469
# Epoch 57/100
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0075 - root_mean_squared_error: 0.0771 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0564
# Epoch 58/100
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0075 - root_mean_squared_error: 0.0768 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0478
# Epoch 59/100
# 384/384 [==============================] - 3s 7ms/step - loss: 0.0075 - root_mean_squared_error: 0.0769 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0520
# Epoch 60/100
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0076 - root_mean_squared_error: 0.0775 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0514
# Epoch 61/100
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0074 - root_mean_squared_error: 0.0766 - val_loss: 0.0040 - val_root_mean_squared_error: 0.0494
# Epoch 62/100
# 384/384 [==============================] - 2s 7ms/step - loss: 0.0071 - root_mean_squared_error: 0.0747 - val_loss: 0.0036 - val_root_mean_squared_error: 0.0456
# Epoch 63/100
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0076 - root_mean_squared_error: 0.0778 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0549
# Epoch 64/100
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0076 - root_mean_squared_error: 0.0778 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0475
# Epoch 65/100
# 384/384 [==============================] - 3s 7ms/step - loss: 0.0073 - root_mean_squared_error: 0.0761 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0469
# Epoch 66/100
# 384/384 [==============================] - 3s 7ms/step - loss: 0.0072 - root_mean_squared_error: 0.0758 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0537
# Epoch 67/100
# 384/384 [==============================] - 3s 7ms/step - loss: 0.0072 - root_mean_squared_error: 0.0761 - val_loss: 0.0036 - val_root_mean_squared_error: 0.0458
# Epoch 68/100
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0074 - root_mean_squared_error: 0.0770 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0541
# Epoch 69/100
# 384/384 [==============================] - 3s 7ms/step - loss: 0.0072 - root_mean_squared_error: 0.0758 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0522
# Epoch 70/100
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0071 - root_mean_squared_error: 0.0754 - val_loss: 0.0040 - val_root_mean_squared_error: 0.0506
# Epoch 71/100
# 384/384 [==============================] - 3s 7ms/step - loss: 0.0073 - root_mean_squared_error: 0.0765 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0487
# Epoch 72/100
# 384/384 [==============================] - 3s 7ms/step - loss: 0.0070 - root_mean_squared_error: 0.0749 - val_loss: 0.0040 - val_root_mean_squared_error: 0.0517
# Epoch 73/100
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0073 - root_mean_squared_error: 0.0771 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0416
# Epoch 74/100
# 384/384 [==============================] - 3s 7ms/step - loss: 0.0071 - root_mean_squared_error: 0.0756 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0456
# Epoch 75/100
# 384/384 [==============================] - 3s 7ms/step - loss: 0.0073 - root_mean_squared_error: 0.0767 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0473
# Epoch 76/100
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0076 - root_mean_squared_error: 0.0779 - val_loss: 0.0040 - val_root_mean_squared_error: 0.0507
# Epoch 77/100
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0071 - root_mean_squared_error: 0.0759 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0427
# Epoch 78/100
# 384/384 [==============================] - 3s 7ms/step - loss: 0.0070 - root_mean_squared_error: 0.0748 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0539
# Epoch 79/100
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0071 - root_mean_squared_error: 0.0765 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0491
# Epoch 80/100
# 384/384 [==============================] - 3s 7ms/step - loss: 0.0071 - root_mean_squared_error: 0.0760 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0560
# Epoch 81/100
# 384/384 [==============================] - 3s 7ms/step - loss: 0.0072 - root_mean_squared_error: 0.0766 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0465
# Epoch 82/100
# 384/384 [==============================] - 3s 7ms/step - loss: 0.0071 - root_mean_squared_error: 0.0765 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0597
# Epoch 83/100
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0073 - root_mean_squared_error: 0.0776 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0458
# Epoch 84/100
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0069 - root_mean_squared_error: 0.0750 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0571
# Epoch 85/100
# 384/384 [==============================] - 3s 7ms/step - loss: 0.0073 - root_mean_squared_error: 0.0775 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0610
# Epoch 86/100
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0070 - root_mean_squared_error: 0.0757 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0449
# Epoch 87/100
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0068 - root_mean_squared_error: 0.0744 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0553
# Epoch 88/100
# 384/384 [==============================] - 3s 7ms/step - loss: 0.0071 - root_mean_squared_error: 0.0762 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0450
# Epoch 89/100
# 384/384 [==============================] - 3s 7ms/step - loss: 0.0070 - root_mean_squared_error: 0.0757 - val_loss: 0.0040 - val_root_mean_squared_error: 0.0521
# Epoch 90/100
# 384/384 [==============================] - 3s 9ms/step - loss: 0.0071 - root_mean_squared_error: 0.0762 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0495
# Epoch 91/100
# 384/384 [==============================] - 3s 8ms/step - loss: 0.0072 - root_mean_squared_error: 0.0773 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0421
# Epoch 92/100
# 384/384 [==============================] - 3s 8ms/step - loss: 0.0067 - root_mean_squared_error: 0.0740 - val_loss: 0.0040 - val_root_mean_squared_error: 0.0526
# Epoch 93/100
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0069 - root_mean_squared_error: 0.0754 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0516
# Epoch 94/100
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0070 - root_mean_squared_error: 0.0758 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0508
# Epoch 95/100
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0068 - root_mean_squared_error: 0.0746 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0463
# Epoch 96/100
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0069 - root_mean_squared_error: 0.0757 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0471
# Epoch 97/100
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0069 - root_mean_squared_error: 0.0754 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0511
# Epoch 98/100
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0069 - root_mean_squared_error: 0.0759 - val_loss: 0.0029 - val_root_mean_squared_error: 0.0423
# Epoch 99/100
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0068 - root_mean_squared_error: 0.0752 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0455
# Epoch 100/100
# 384/384 [==============================] - 3s 7ms/step - loss: 0.0068 - root_mean_squared_error: 0.0750 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0474

# %%
# 绘制损失函数曲线
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'val'], loc='upper right')
plt.show()

# %%
y_pred = model.predict(x_test_single)

# %%
print(y_pred)

max_target =202.22884  # 原始数据中的最大值
min_target = 0.25836  # 原始数据中的最小值

y_pred_unnormalized = y_pred * (max_target - min_target) + min_target

y_test_single_unnormalized = y_test_single * (max_target - min_target) + min_target



y_pred_original = y_pred_unnormalized
y_test_original = y_test_single_unnormalized

print(y_pred_original)
# Out:
# [[0.33789772]
#  [0.2404988 ]
#  [0.16811407]
#  ...
#  [0.5907067 ]
#  [0.61624366]
#  [0.57151234]]
# [[ 68.50372 ]
#  [ 48.832016]
#  [ 34.21244 ]
#  ...
#  [119.563675]
#  [124.72139 ]
#  [115.68698 ]]

# %%
# 计算均方误差 (MSE) 和均方根误差 (RMSE)
from sklearn.metrics import mean_squared_error, mean_absolute_error,r2_score,explained_variance_score


# 计算NRMSE
def normalized_root_mean_squared_error(y_true, y_pred):
    mse = mean_squared_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    range_y = np.max(y_true) - np.min(y_true)
    return rmse / range_y

mse = mean_squared_error(y_test_original, y_pred_original)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test_original, y_pred_original)
# 计算 MBE
mbe = np.mean(y_test_original - y_pred_original)
nrmse = normalized_root_mean_squared_error(y_test_original, y_pred_original)
r2 = r2_score(y_test_original, y_pred_original)
evs = explained_variance_score(y_test_original, y_pred_original)
print("Mean Squared Error (MSE):", mse)
print("Root Mean Squared Error (RMSE):", rmse)
print("Mean Absolute Error (MAE):", mae)
print("Mean Bias Error(MBE):",mbe)
print("NRMSE:", nrmse)
print("Explained Variance Score (EVS):", evs)
print("R² Score:", r2)
# Out:
# Mean Squared Error (MSE): 83.5040179992691
# Root Mean Squared Error (RMSE): 9.138053293742004
# Mean Absolute Error (MAE): 5.497307075738515
# Mean Bias Error(MBE): 3.464687713818949
# NRMSE: 0.04530868173509206
# Explained Variance Score (EVS): 0.965323736089756
# R² Score: 0.9595019705552162

# %%
# 创建一个新图表
plt.figure(figsize=(10, 6))

# 绘制 y_test_original（蓝色折线）
plt.plot(y_test_original, label='Actual', color='blue')

# 绘制 y_pred_original（红色折线）
plt.plot(y_pred_original, label='Predicted', color='red')

# 添加图例
plt.legend()

# 设置横轴和纵轴标签
plt.xlabel('Time')
plt.ylabel('Value')

# 设置图表标题
plt.title('Actual vs. Predicted Data')

# 显示图表
plt.show()


'''
Mean Squared Error (MSE): 86.41694553669562
Root Mean Squared Error (RMSE): 9.296071510949968
Mean Absolute Error (MAE): 5.753434113757974
Mean Bias Error(MBE): 3.6101429384502537
NRMSE: 0.04609217433265935
Explained Variance Score (EVS): 0.9644100977279202
R² Score: 0.9580892502094449

Mean Squared Error (MSE): 83.5040179992691
Root Mean Squared Error (RMSE): 9.138053293742004
Mean Absolute Error (MAE): 5.497307075738515
Mean Bias Error(MBE): 3.464687713818949
NRMSE: 0.04530868173509206
Explained Variance Score (EVS): 0.965323736089756
R² Score: 0.9595019705552162
'''
