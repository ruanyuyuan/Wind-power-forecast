# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('wind2019.csv')
df.head(100)
# Out:
#                      时间  测风塔10m风速(m/s)  测风塔30m风速(m/s)  测风塔50m风速(m/s)  \
# 0   2019-01-01 00:00:00          0.223          0.000          0.000
# 1   2019-01-01 00:15:00          0.000          0.000          0.000
# 2   2019-01-01 00:30:00          0.000          0.000          0.000
# 3   2019-01-01 00:45:00          0.818          0.000          0.000
# 4   2019-01-01 01:00:00          1.041          0.000          0.297
# ..                  ...            ...            ...            ...
# 95  2019-01-01 23:45:00          3.155          3.461          2.798
# 96  2019-01-02 00:00:00          2.543          2.798          2.033
# 97  2019-01-02 00:15:00          1.829          2.747          2.135
# 98  2019-01-02 00:30:00          2.645          2.033          2.390
# 99  2019-01-02 00:45:00          3.308          2.135          2.849
#
#     测风塔10m风向(°)  测风塔30m风向(°)  测风塔50m风向(°)   温度(°)  气压(hPa)   湿度(%)  实际发电功率（mw）
# 0       166.816      177.355        6.224 -13.154  898.710  53.497    0.979591
# 1       166.832      177.356        6.526 -13.864  898.621  55.999    1.150984
# 2       166.859      177.353       28.936 -14.461  898.497  57.747    1.066162
# 3       166.894      177.344       29.212 -13.066  898.329  54.162    0.923717
# 4       166.892      177.352       29.378 -12.823  898.356  52.807    0.813552
# ..          ...          ...          ...     ...      ...     ...         ...
# 95      169.334      161.863        6.641 -11.289  892.893  51.098    0.954867
# 96      169.808      167.790        6.497 -11.851  892.889  52.669    1.301044
# 97      183.806      178.947        6.696 -11.293  892.827  51.019    1.229518
# 98      160.364      186.116        6.881 -12.165  892.663  53.786    1.001882
# 99      157.742      187.094        6.902 -13.097  892.566  57.127    0.953660
#
# [100 rows x 11 columns]

# %%
idx_df = df.set_index(['时间'])
idx_df.describe().T  #用于计算数值列的描述性统计信息，如计数、均值、标准差、最小值、最大值等
# Out:
#                  count        mean        std        min        25%  \
# 测风塔10m风速(m/s)  35040.0    4.818662   3.516523    0.00000    2.36400
# 测风塔30m风速(m/s)  35040.0    5.347264   3.836181    0.00000    2.62000
# 测风塔50m风速(m/s)  35040.0    5.773827   4.053695    0.00000    2.77200
# 测风塔10m风向(°)    35040.0  156.220382  86.821714    0.00000   82.25375
# 测风塔30m风向(°)    35040.0  158.638939  89.835426    0.00000   79.70725
# 测风塔50m风向(°)    35040.0   11.587642  16.812424    0.00000    5.85200
# 温度(°)          35040.0   11.324763  14.027540  -18.66200   -1.57650
# 气压(hPa)        35040.0  888.509122   5.793348  874.58400  883.63200
# 湿度(%)          35040.0   33.592505  20.761404    2.50600   16.64700
# 实际发电功率（mw）     35040.0   53.907954  56.733980    0.25836    3.52621
#
#                       50%        75%        max
# 测风塔10m风速(m/s)    3.869000    6.60200   19.24600
# 测风塔30m风速(m/s)    4.481000    7.31200   21.05600
# 测风塔50m风速(m/s)    4.660000    8.00000   22.38200
# 测风塔10m风向(°)    137.966500  230.50950  359.94600
# 测风塔30m风向(°)    137.621000  239.89550  360.00000
# 测风塔50m风向(°)      6.392000   11.53925  355.82300
# 温度(°)           13.105500   23.04225   40.13100
# 气压(hPa)        888.638000  892.70800  905.30700
# 湿度(%)           28.122000   47.54425   94.92100
# 实际发电功率（mw）      29.037047   99.74149  202.22884

# %%
idx_df.head(10)
# Out:
#                      测风塔10m风速(m/s)  测风塔30m风速(m/s)  测风塔50m风速(m/s)  测风塔10m风向(°)  \
# 时间
# 2019-01-01 00:00:00          0.223          0.000          0.000      166.816
# 2019-01-01 00:15:00          0.000          0.000          0.000      166.832
# 2019-01-01 00:30:00          0.000          0.000          0.000      166.859
# 2019-01-01 00:45:00          0.818          0.000          0.000      166.894
# 2019-01-01 01:00:00          1.041          0.000          0.297      166.892
# 2019-01-01 01:15:00          1.676          0.520          1.319      166.916
# 2019-01-01 01:30:00          2.645          1.472          2.033      166.872
# 2019-01-01 01:45:00          1.880          2.747          2.339      176.703
# 2019-01-01 02:00:00          1.676          2.543          2.543      176.739
# 2019-01-01 02:15:00          0.000          0.149          2.798      176.704
#
#                      测风塔30m风向(°)  测风塔50m风向(°)   温度(°)  气压(hPa)   湿度(%)  \
# 时间
# 2019-01-01 00:00:00      177.355        6.224 -13.154  898.710  53.497
# 2019-01-01 00:15:00      177.356        6.526 -13.864  898.621  55.999
# 2019-01-01 00:30:00      177.353       28.936 -14.461  898.497  57.747
# 2019-01-01 00:45:00      177.344       29.212 -13.066  898.329  54.162
# 2019-01-01 01:00:00      177.352       29.378 -12.823  898.356  52.807
# 2019-01-01 01:15:00      177.356       12.255 -12.793  898.196  51.031
# 2019-01-01 01:30:00      177.280        6.489 -13.671  898.076  53.597
# 2019-01-01 01:45:00      192.212        8.162 -13.905  897.939  54.602
# 2019-01-01 02:00:00      206.758        9.875 -13.270  897.775  53.981
# 2019-01-01 02:15:00      206.675        9.206 -13.598  897.779  54.478
#
#                      实际发电功率（mw）
# 时间
# 2019-01-01 00:00:00    0.979591
# 2019-01-01 00:15:00    1.150984
# 2019-01-01 00:30:00    1.066162
# 2019-01-01 00:45:00    0.923717
# 2019-01-01 01:00:00    0.813552
# 2019-01-01 01:15:00    1.385237
# 2019-01-01 01:30:00    5.187509
# 2019-01-01 01:45:00    8.714045
# 2019-01-01 02:00:00   11.367244
# 2019-01-01 02:15:00   11.250483

# %%
idx_df.isnull().sum()#DataFrame 中每列的缺失值数量。通过这个操作，您可以了解每列中缺失值的分布情况，并进行进一步的数据清洗或处理。
# Out:
# 测风塔10m风速(m/s)    0
# 测风塔30m风速(m/s)    0
# 测风塔50m风速(m/s)    0
# 测风塔10m风向(°)      0
# 测风塔30m风向(°)      0
# 测风塔50m风向(°)      0
# 温度(°)            0
# 气压(hPa)          0
# 湿度(%)            0
# 实际发电功率（mw）       0
# dtype: int64

# %%
import matplotlib.font_manager as font_manager

# 指定中文字体文件路径
font_path = 'C:/Windows/Fonts/simsun.ttc'

# 加载中文字体
prop = font_manager.FontProperties(fname=font_path)

# 设置中文字体为默认字体
plt.rcParams['font.family'] = prop.get_name()
fig,ax = plt.subplots(figsize = (10,10))
sns.heatmap(idx_df.corr(),ax=ax,annot = True)
# Out:
# D:\JetBrains\ANACONDA\envs\py37\lib\site-packages\seaborn\utils.py:80: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.draw()
# <AxesSubplot:>
# D:\JetBrains\ANACONDA\envs\py37\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   func(*args, **kwargs)
# D:\JetBrains\ANACONDA\envs\py37\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
idx_df.corr()['实际发电功率（mw）'].sort_values(ascending=False)
# Out:
# 实际发电功率（mw）       1.000000
# 测风塔50m风速(m/s)    0.784718
# 测风塔30m风速(m/s)    0.761795
# 测风塔10m风速(m/s)    0.746070
# 温度(°)            0.132965
# 气压(hPa)         -0.127836
# 湿度(%)           -0.136031
# 测风塔50m风向(°)     -0.190069
# 测风塔10m风向(°)     -0.344054
# 测风塔30m风向(°)     -0.369254
# Name: 实际发电功率（mw）, dtype: float64

# %%
idx_df.shape
# Out:
# (35040, 10)

# %%
idx_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 35040 entries, 2019-01-01 00:00:00 to 2019-12-31 23:45:00
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   测风塔10m风速(m/s)  35040 non-null  float64
#  1   测风塔30m风速(m/s)  35040 non-null  float64
#  2   测风塔50m风速(m/s)  35040 non-null  float64
#  3   测风塔10m风向(°)    35040 non-null  float64
#  4   测风塔30m风向(°)    35040 non-null  float64
#  5   测风塔50m风向(°)    35040 non-null  float64
#  6   温度(°)          35040 non-null  float64
#  7   气压(hPa)        35040 non-null  float64
#  8   湿度(%)          35040 non-null  float64
#  9   实际发电功率（mw）     35040 non-null  float64
# dtypes: float64(10)
# memory usage: 2.9+ MB

# %%
df2 = idx_df.drop(['测风塔30m风向(°)','测风塔10m风向(°)'],axis=1)

x = df2.iloc[:,:].values #转化成numpy类型
print(x)
print(x.shape)
# Out:
# [[2.23000000e-01 0.00000000e+00 0.00000000e+00 ... 8.98710000e+02
#   5.34970000e+01 9.79591000e-01]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 8.98621000e+02
#   5.59990000e+01 1.15098400e+00]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 8.98497000e+02
#   5.77470000e+01 1.06616200e+00]
#  ...
#  [7.46400000e+00 8.15300000e+00 8.76500000e+00 ... 8.88383000e+02
#   4.11360000e+01 1.34717210e+02]
#  [5.70500000e+00 7.15800000e+00 8.07600000e+00 ... 8.88389000e+02
#   4.12880000e+01 1.26557410e+02]
#  [7.15800000e+00 8.00000000e+00 9.68300000e+00 ... 8.88469000e+02
#   4.01230000e+01 1.09673615e+02]]
# (35040, 8)

# %%
from sklearn.preprocessing import MinMaxScaler
x_sc = MinMaxScaler()
x = x_sc.fit_transform(x)
# print(x.shape)
# print(x)

# 获取归一化时用的最大值和最小值
max_values = x_sc.data_max_
min_values = x_sc.data_min_

# 打印每个特征的最大值和最小值
for feature, max_val, min_val in zip(range(len(max_values)), max_values, min_values):
    print(f"Feature {feature}: Max Value = {max_val}, Min Value = {min_val}")
# Out:
# Feature 0: Max Value = 19.246, Min Value = 0.0
# Feature 1: Max Value = 21.055999999999997, Min Value = 0.0
# Feature 2: Max Value = 22.381999999999998, Min Value = 0.0
# Feature 3: Max Value = 355.82300000000004, Min Value = 0.0
# Feature 4: Max Value = 40.131, Min Value = -18.662
# Feature 5: Max Value = 905.307, Min Value = 874.584
# Feature 6: Max Value = 94.921, Min Value = 2.506
# Feature 7: Max Value = 202.22884, Min Value = 0.25836

# %%
# 滑动窗口截取数据

def multivariate_data(dataset, target, start_index, end_index, history_size,
                      target_size, step, single_step=False):
    data = []
    labels = []

    start_index = start_index + history_size
    
    if end_index is None:
        end_index = len(dataset) - target_size

    for i in range(start_index, end_index):
        indices = range(i-history_size, i, step) # step表示滑动步长
        data.append(dataset[indices])

        if single_step:
            labels.append(target[i+target_size])
        else:
            labels.append(target[i:i+target_size])

    return np.array(data), np.array(labels)

# %%
past_history = 8  #2小时观测值
future_target = 0  #下一个时间点的功率值
STEP = 1

x_train_single, y_train_single = multivariate_data(x, x[:, -1], 0,
                                                   24528, past_history,
                                                   future_target, STEP,
                                                   single_step=True)
x_val_single, y_val_single = multivariate_data(x, x[:, -1],
                                              24528 , 31536, past_history,
                                               future_target, STEP,
                                               single_step=True)
x_test_single, y_test_single = multivariate_data(x, x[:, -1],
                                               31536, None, past_history,
                                               future_target, STEP,
                                               single_step=True)
print(y_train_single.shape)
print(y_train_single)
# print(x_val_single.shape)
# print(x_test_single.shape)
# print(x_train_single)
# print(y_test_single.shape)
# Out:
# (24520,)
# [0.05500251 0.0544244  0.04823228 ... 0.0103412  0.0256572  0.02965432]

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import LSTM,Bidirectional,GRU,Input, Conv1D,Multiply,Flatten,MaxPooling1D,concatenate,GlobalAveragePooling1D,Reshape
from tensorflow.keras.layers import Dense, Activation, BatchNormalization, Dropout,Permute,Lambda,RepeatVector
from tensorflow.keras import regularizers
from tensorflow.keras.optimizers import RMSprop, Adam, SGD
import datetime
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow.keras.backend as K
# from tensorflow.keras_self_attention import SeqSelfAttention
from tensorflow.keras.models import Model
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.callbacks import ReduceLROnPlateau,ModelCheckpoint

# %%
#通道注意力机制
def SE_Block(input_tensor,ratio = 2):
    input_shape = K.int_shape(input_tensor)
    squeeze = tf.keras.layers.GlobalAveragePooling1D()(input_tensor)
    excitation = tf.keras.layers.Dense(units = input_shape[-1]//ratio, kernel_initializer='he_normal',activation='relu')(squeeze)
    excitation = tf.keras.layers.Dense(units = input_shape[-1],activation='sigmoid')(excitation)
    #excitation = tf.reshape(excitation, [-1, 1, input_shape[-1]])
    scale = tf.keras.layers.Multiply()([input_tensor, excitation])
    return scale
def double_SENet_BiGRU():
    visible1 = Input(shape=(8, 8))
#     cnn1 = Conv1D(filters=8, kernel_size=1, activation='relu',padding='same')(visible1)   #output_length = seq_length - kernel_size + 1=24-3+1=22  (22,8)
#     cnn1 = MaxPooling1D(pool_size=2)(cnn1)  #output_length = ceil(seq_length / pool_size)=22/2=11   (11,8)
#     cnn2 = Conv1D(filters=16, kernel_size=3, activation='relu')(cnn1)  #11-3+1=9   (9,16)
#     cnn2 = MaxPooling1D(pool_size=2)(cnn2)   # (9/2,16)=(4,16)
#     cnn = Flatten()(cnn2)  #4*16=64
#     cnn2_with_se = SE_Block(visible1, ratio=8)
#     SENet = Flatten()(cnn2_with_se)

#     cs = SE_Block(visible1,ratio = 2)
    cnn1 = Conv1D(filters=8, kernel_size=1, activation='relu', padding='same')(visible1)
#     cnn1 = MaxPooling1D(pool_size=2)(cnn1)
    cs = SE_Block(cnn1,ratio = 2)
    cnn2 = Conv1D(filters=16, kernel_size=3, activation='relu',padding='same')(cs)  #11-3+1=9   (9,16)
    cnn2 = MaxPooling1D(pool_size=2)(cnn2)   # (9/2,16)=(4,16)
    cnn = Flatten()(cnn2)
    
    visible2 = Input(shape=(8, 8))  
    gru1 = Bidirectional(GRU(units=32, return_sequences=True,kernel_regularizer=tf.keras.regularizers.l2(0.01)))(visible2)  #(24,32)
    gru2 = Bidirectional(GRU(units=16, return_sequences=False,kernel_regularizer=tf.keras.regularizers.l2(0.01)))(gru1)
    gru = Flatten()(gru2)
    
    merge = concatenate([cnn, gru])
    
#     # 添加自注意力层
#     self_attention_layer = SelfAttention(d_model=32)  # 假设自注意力层的输出维度为32
#     attention = self_attention_layer(merge)
    # 用于将输入层的数据压成一维的数据，一般用再卷积层和全连接层之间
    attention_probs = Dense(96, activation='sigmoid', name='attention_vec')(merge)
    attention_mul = Multiply()([merge, attention_probs])
    F = Flatten()(attention_mul)
    
    dense = Dense(units=64, activation='relu')(F)
    output = Dense(units=1,activation='relu')(dense)
    model = Model(inputs=[visible1, visible2], outputs=output)
    adam = Adam(learning_rate=0.042205)
    return model

# %%
m = double_SENet_BiGRU()
m.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 8, 8)]       0
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 8, 8)         72          input_3[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_1 (Glo (None, 8)            0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 4)            36          global_average_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 8)            40          dense_2[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 8, 8)         0           conv1d_2[0][0]
#                                                                  dense_3[0][0]
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, 8, 8)]       0
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 8, 16)        400         multiply_1[0][0]
# __________________________________________________________________________________________________
# bidirectional_2 (Bidirectional) (None, 8, 64)        8064        input_4[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_1 (MaxPooling1D)  (None, 4, 16)        0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# bidirectional_3 (Bidirectional) (None, 32)           7872        bidirectional_2[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 64)           0           max_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# flatten_3 (Flatten)             (None, 32)           0           bidirectional_3[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 96)           0           flatten_2[0][0]
#                                                                  flatten_3[0][0]
# __________________________________________________________________________________________________
# attention_vec (Dense)           (None, 96)           9312        concatenate[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 96)           0           concatenate[0][0]
#                                                                  attention_vec[0][0]
# __________________________________________________________________________________________________
# flatten_4 (Flatten)             (None, 96)           0           multiply_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 64)           6208        flatten_4[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 1)            65          dense_4[0][0]
# ==================================================================================================
# Total params: 32,069
# Trainable params: 32,069
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
m.compile(optimizer='adam', loss='mse',metrics = [tf.keras.metrics.RootMeanSquaredError()])
hist = m.fit([x_train_single,x_train_single],y_train_single,epochs=100, batch_size=126,  validation_data=([x_val_single,x_val_single], y_val_single),verbose=1)
# Out:
# Epoch 1/100
# 195/195 [==============================] - 8s 16ms/step - loss: 0.8735 - root_mean_squared_error: 0.1690 - val_loss: 0.0842 - val_root_mean_squared_error: 0.0753
# Epoch 2/100
# 195/195 [==============================] - 2s 10ms/step - loss: 0.0472 - root_mean_squared_error: 0.0691 - val_loss: 0.0065 - val_root_mean_squared_error: 0.0598
# Epoch 3/100
# 195/195 [==============================] - 2s 10ms/step - loss: 0.0051 - root_mean_squared_error: 0.0569 - val_loss: 0.0023 - val_root_mean_squared_error: 0.0429
# Epoch 4/100
# 195/195 [==============================] - 2s 9ms/step - loss: 0.0030 - root_mean_squared_error: 0.0509 - val_loss: 0.0020 - val_root_mean_squared_error: 0.0414
# Epoch 5/100
# 195/195 [==============================] - 2s 10ms/step - loss: 0.0025 - root_mean_squared_error: 0.0479 - val_loss: 0.0020 - val_root_mean_squared_error: 0.0423
# Epoch 6/100
# 195/195 [==============================] - 2s 11ms/step - loss: 0.0025 - root_mean_squared_error: 0.0477 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0397
# Epoch 7/100
# 195/195 [==============================] - 2s 8ms/step - loss: 0.0023 - root_mean_squared_error: 0.0462 - val_loss: 0.0021 - val_root_mean_squared_error: 0.0453
# Epoch 8/100
# 195/195 [==============================] - 2s 8ms/step - loss: 0.0023 - root_mean_squared_error: 0.0469 - val_loss: 0.0014 - val_root_mean_squared_error: 0.0371
# Epoch 9/100
# 195/195 [==============================] - 2s 9ms/step - loss: 0.0021 - root_mean_squared_error: 0.0454 - val_loss: 0.0014 - val_root_mean_squared_error: 0.0375
# Epoch 10/100
# 195/195 [==============================] - 2s 8ms/step - loss: 0.0023 - root_mean_squared_error: 0.0473 - val_loss: 0.0015 - val_root_mean_squared_error: 0.0385
# Epoch 11/100
# 195/195 [==============================] - 2s 9ms/step - loss: 0.0020 - root_mean_squared_error: 0.0442 - val_loss: 0.0015 - val_root_mean_squared_error: 0.0383
# Epoch 12/100
# 195/195 [==============================] - 2s 10ms/step - loss: 0.0021 - root_mean_squared_error: 0.0454 - val_loss: 0.0014 - val_root_mean_squared_error: 0.0368
# Epoch 13/100
# 195/195 [==============================] - 2s 9ms/step - loss: 0.0021 - root_mean_squared_error: 0.0461 - val_loss: 0.0015 - val_root_mean_squared_error: 0.0387
# Epoch 14/100
# 195/195 [==============================] - 2s 9ms/step - loss: 0.0020 - root_mean_squared_error: 0.0447 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0345
# Epoch 15/100
# 195/195 [==============================] - 2s 10ms/step - loss: 0.0018 - root_mean_squared_error: 0.0429 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0348
# Epoch 16/100
# 195/195 [==============================] - 2s 9ms/step - loss: 0.0019 - root_mean_squared_error: 0.0431 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0343
# Epoch 17/100
# 195/195 [==============================] - 2s 10ms/step - loss: 0.0019 - root_mean_squared_error: 0.0436 - val_loss: 0.0015 - val_root_mean_squared_error: 0.0387
# Epoch 18/100
# 195/195 [==============================] - 2s 9ms/step - loss: 0.0018 - root_mean_squared_error: 0.0427 - val_loss: 0.0013 - val_root_mean_squared_error: 0.0356
# Epoch 19/100
# 195/195 [==============================] - 2s 9ms/step - loss: 0.0020 - root_mean_squared_error: 0.0446 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0349
# Epoch 20/100
# 195/195 [==============================] - 2s 10ms/step - loss: 0.0018 - root_mean_squared_error: 0.0429 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0339
# Epoch 21/100
# 195/195 [==============================] - 2s 9ms/step - loss: 0.0019 - root_mean_squared_error: 0.0432 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0342
# Epoch 22/100
# 195/195 [==============================] - 2s 11ms/step - loss: 0.0019 - root_mean_squared_error: 0.0440 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0336
# Epoch 23/100
# 195/195 [==============================] - 3s 17ms/step - loss: 0.0018 - root_mean_squared_error: 0.0428 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0338
# Epoch 24/100
# 195/195 [==============================] - 2s 11ms/step - loss: 0.0018 - root_mean_squared_error: 0.0423 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0335
# Epoch 25/100
# 195/195 [==============================] - 2s 10ms/step - loss: 0.0018 - root_mean_squared_error: 0.0430 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0338
# Epoch 26/100
# 195/195 [==============================] - 2s 11ms/step - loss: 0.0019 - root_mean_squared_error: 0.0435 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0332
# Epoch 27/100
# 195/195 [==============================] - 2s 12ms/step - loss: 0.0018 - root_mean_squared_error: 0.0425 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0349
# Epoch 28/100
# 195/195 [==============================] - 2s 12ms/step - loss: 0.0018 - root_mean_squared_error: 0.0422 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0335
# Epoch 29/100
# 195/195 [==============================] - 2s 12ms/step - loss: 0.0019 - root_mean_squared_error: 0.0431 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0346
# Epoch 30/100
# 195/195 [==============================] - 2s 10ms/step - loss: 0.0019 - root_mean_squared_error: 0.0434 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0330
# Epoch 31/100
# 195/195 [==============================] - 3s 13ms/step - loss: 0.0017 - root_mean_squared_error: 0.0416 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0329
# Epoch 32/100
# 195/195 [==============================] - 2s 11ms/step - loss: 0.0018 - root_mean_squared_error: 0.0423 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0333
# Epoch 33/100
# 195/195 [==============================] - 2s 12ms/step - loss: 0.0019 - root_mean_squared_error: 0.0431 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0331
# Epoch 34/100
# 195/195 [==============================] - 2s 10ms/step - loss: 0.0018 - root_mean_squared_error: 0.0427 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0342
# Epoch 35/100
# 195/195 [==============================] - 2s 12ms/step - loss: 0.0018 - root_mean_squared_error: 0.0429 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0330
# Epoch 36/100
# 195/195 [==============================] - 2s 10ms/step - loss: 0.0019 - root_mean_squared_error: 0.0435 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0328
# Epoch 37/100
# 195/195 [==============================] - 2s 9ms/step - loss: 0.0018 - root_mean_squared_error: 0.0426 - val_loss: 0.0014 - val_root_mean_squared_error: 0.0373
# Epoch 38/100
# 195/195 [==============================] - 2s 11ms/step - loss: 0.0018 - root_mean_squared_error: 0.0427 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0343
# Epoch 39/100
# 195/195 [==============================] - 2s 9ms/step - loss: 0.0019 - root_mean_squared_error: 0.0431 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0342
# Epoch 40/100
# 195/195 [==============================] - 2s 9ms/step - loss: 0.0019 - root_mean_squared_error: 0.0433 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0334
# Epoch 41/100
# 195/195 [==============================] - 2s 10ms/step - loss: 0.0019 - root_mean_squared_error: 0.0437 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0337
# Epoch 42/100
# 195/195 [==============================] - 2s 10ms/step - loss: 0.0018 - root_mean_squared_error: 0.0425 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0328
# Epoch 43/100
# 195/195 [==============================] - 2s 10ms/step - loss: 0.0018 - root_mean_squared_error: 0.0428 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0331
# Epoch 44/100
# 195/195 [==============================] - 2s 9ms/step - loss: 0.0017 - root_mean_squared_error: 0.0415 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0329
# Epoch 45/100
# 195/195 [==============================] - 2s 11ms/step - loss: 0.0019 - root_mean_squared_error: 0.0431 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0344
# Epoch 46/100
# 195/195 [==============================] - 2s 11ms/step - loss: 0.0018 - root_mean_squared_error: 0.0422 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0330
# Epoch 47/100
# 195/195 [==============================] - 2s 9ms/step - loss: 0.0018 - root_mean_squared_error: 0.0425 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0335
# Epoch 48/100
# 195/195 [==============================] - 2s 10ms/step - loss: 0.0018 - root_mean_squared_error: 0.0429 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0334
# Epoch 49/100
# 195/195 [==============================] - 2s 9ms/step - loss: 0.0019 - root_mean_squared_error: 0.0431 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0351
# Epoch 50/100
# 195/195 [==============================] - 2s 10ms/step - loss: 0.0018 - root_mean_squared_error: 0.0430 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0334
# Epoch 51/100
# 195/195 [==============================] - 2s 11ms/step - loss: 0.0018 - root_mean_squared_error: 0.0430 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0328
# Epoch 52/100
# 195/195 [==============================] - 2s 9ms/step - loss: 0.0018 - root_mean_squared_error: 0.0423 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0328
# Epoch 53/100
# 195/195 [==============================] - 2s 10ms/step - loss: 0.0018 - root_mean_squared_error: 0.0421 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0326
# Epoch 54/100
# 195/195 [==============================] - 2s 10ms/step - loss: 0.0018 - root_mean_squared_error: 0.0419 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0335
# Epoch 55/100
# 195/195 [==============================] - 2s 9ms/step - loss: 0.0018 - root_mean_squared_error: 0.0424 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0341
# Epoch 56/100
# 195/195 [==============================] - 2s 10ms/step - loss: 0.0018 - root_mean_squared_error: 0.0424 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0328
# Epoch 57/100
# 195/195 [==============================] - 2s 10ms/step - loss: 0.0018 - root_mean_squared_error: 0.0420 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0329
# Epoch 58/100
# 195/195 [==============================] - 2s 10ms/step - loss: 0.0018 - root_mean_squared_error: 0.0422 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0330
# Epoch 59/100
# 195/195 [==============================] - 2s 10ms/step - loss: 0.0018 - root_mean_squared_error: 0.0424 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0328
# Epoch 60/100
# 195/195 [==============================] - 2s 9ms/step - loss: 0.0017 - root_mean_squared_error: 0.0416 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0327
# Epoch 61/100
# 195/195 [==============================] - 2s 9ms/step - loss: 0.0018 - root_mean_squared_error: 0.0425 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0328
# Epoch 62/100
# 195/195 [==============================] - 2s 10ms/step - loss: 0.0018 - root_mean_squared_error: 0.0424 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0326
# Epoch 63/100
# 195/195 [==============================] - 2s 10ms/step - loss: 0.0018 - root_mean_squared_error: 0.0426 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0332
# Epoch 64/100
# 195/195 [==============================] - 2s 10ms/step - loss: 0.0017 - root_mean_squared_error: 0.0409 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0333
# Epoch 65/100
# 195/195 [==============================] - 2s 9ms/step - loss: 0.0018 - root_mean_squared_error: 0.0424 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0332
# Epoch 66/100
# 195/195 [==============================] - 2s 9ms/step - loss: 0.0018 - root_mean_squared_error: 0.0425 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0330
# Epoch 67/100
# 195/195 [==============================] - 2s 9ms/step - loss: 0.0018 - root_mean_squared_error: 0.0427 - val_loss: 0.0013 - val_root_mean_squared_error: 0.0359
# Epoch 68/100
# 195/195 [==============================] - 2s 9ms/step - loss: 0.0018 - root_mean_squared_error: 0.0419 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0334
# Epoch 69/100
# 195/195 [==============================] - 2s 9ms/step - loss: 0.0017 - root_mean_squared_error: 0.0418 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0328
# Epoch 70/100
# 195/195 [==============================] - 2s 9ms/step - loss: 0.0017 - root_mean_squared_error: 0.0414 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0326
# Epoch 71/100
# 195/195 [==============================] - 2s 10ms/step - loss: 0.0017 - root_mean_squared_error: 0.0418 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0333
# Epoch 72/100
# 195/195 [==============================] - 2s 9ms/step - loss: 0.0018 - root_mean_squared_error: 0.0429 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0327
# Epoch 73/100
# 195/195 [==============================] - 2s 9ms/step - loss: 0.0017 - root_mean_squared_error: 0.0413 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0326
# Epoch 74/100
# 195/195 [==============================] - 2s 9ms/step - loss: 0.0018 - root_mean_squared_error: 0.0422 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0329
# Epoch 75/100
# 195/195 [==============================] - 2s 9ms/step - loss: 0.0018 - root_mean_squared_error: 0.0425 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0333
# Epoch 76/100
# 195/195 [==============================] - 2s 9ms/step - loss: 0.0018 - root_mean_squared_error: 0.0421 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0331
# Epoch 77/100
# 195/195 [==============================] - 2s 9ms/step - loss: 0.0017 - root_mean_squared_error: 0.0417 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0337
# Epoch 78/100
# 195/195 [==============================] - 2s 9ms/step - loss: 0.0017 - root_mean_squared_error: 0.0408 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0328
# Epoch 79/100
# 195/195 [==============================] - 2s 9ms/step - loss: 0.0018 - root_mean_squared_error: 0.0421 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0331
# Epoch 80/100
# 195/195 [==============================] - 2s 9ms/step - loss: 0.0017 - root_mean_squared_error: 0.0415 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0331
# Epoch 81/100
# 195/195 [==============================] - 2s 9ms/step - loss: 0.0017 - root_mean_squared_error: 0.0415 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0335
# Epoch 82/100
# 195/195 [==============================] - 2s 9ms/step - loss: 0.0018 - root_mean_squared_error: 0.0426 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0329
# Epoch 83/100
# 195/195 [==============================] - 2s 9ms/step - loss: 0.0017 - root_mean_squared_error: 0.0416 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0353
# Epoch 84/100
# 195/195 [==============================] - 2s 10ms/step - loss: 0.0018 - root_mean_squared_error: 0.0421 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0330
# Epoch 85/100
# 195/195 [==============================] - 2s 10ms/step - loss: 0.0017 - root_mean_squared_error: 0.0413 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0331
# Epoch 86/100
# 195/195 [==============================] - 2s 9ms/step - loss: 0.0017 - root_mean_squared_error: 0.0412 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0341
# Epoch 87/100
# 195/195 [==============================] - 2s 9ms/step - loss: 0.0018 - root_mean_squared_error: 0.0419 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0325
# Epoch 88/100
# 195/195 [==============================] - 2s 9ms/step - loss: 0.0018 - root_mean_squared_error: 0.0421 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0343
# Epoch 89/100
# 195/195 [==============================] - 2s 9ms/step - loss: 0.0017 - root_mean_squared_error: 0.0413 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0331
# Epoch 90/100
# 195/195 [==============================] - 2s 9ms/step - loss: 0.0017 - root_mean_squared_error: 0.0415 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0340
# Epoch 91/100
# 195/195 [==============================] - 2s 9ms/step - loss: 0.0018 - root_mean_squared_error: 0.0421 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0344
# Epoch 92/100
# 195/195 [==============================] - 2s 9ms/step - loss: 0.0017 - root_mean_squared_error: 0.0416 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0326
# Epoch 93/100
# 195/195 [==============================] - 2s 9ms/step - loss: 0.0018 - root_mean_squared_error: 0.0419 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0329
# Epoch 94/100
# 195/195 [==============================] - 2s 9ms/step - loss: 0.0017 - root_mean_squared_error: 0.0418 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0340
# Epoch 95/100
# 195/195 [==============================] - 2s 9ms/step - loss: 0.0018 - root_mean_squared_error: 0.0420 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0328
# Epoch 96/100
# 195/195 [==============================] - 2s 9ms/step - loss: 0.0017 - root_mean_squared_error: 0.0411 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0334
# Epoch 97/100
# 195/195 [==============================] - 2s 9ms/step - loss: 0.0018 - root_mean_squared_error: 0.0419 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0332
# Epoch 98/100
# 195/195 [==============================] - 2s 9ms/step - loss: 0.0017 - root_mean_squared_error: 0.0409 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0335
# Epoch 99/100
# 195/195 [==============================] - 2s 9ms/step - loss: 0.0017 - root_mean_squared_error: 0.0413 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0333
# Epoch 100/100
# 195/195 [==============================] - 2s 9ms/step - loss: 0.0018 - root_mean_squared_error: 0.0423 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0335

# %%
# 绘制损失函数曲线
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'val'], loc='upper right')
plt.show()

# %%
y_pred = m.predict([x_test_single,x_test_single])

# %%
print(y_pred)

max_target =202.22884  # 原始数据中的最大值
min_target = 0.25836  # 原始数据中的最小值

y_pred_unnormalized = y_pred * (max_target - min_target) + min_target

y_test_single_unnormalized = y_test_single * (max_target - min_target) + min_target



y_pred_original = y_pred_unnormalized
y_test_original = y_test_single_unnormalized

print(y_pred_original)
# Out:
# [[0.33225775]
#  [0.19898942]
#  [0.14437938]
#  ...
#  [0.63484514]
#  [0.6738138 ]
#  [0.6011907 ]]
# [[ 67.36462 ]
#  [ 40.44835 ]
#  [ 29.418732]
#  ...
#  [128.47833 ]
#  [136.34886 ]
#  [121.68113 ]]

# %%
# 计算均方误差 (MSE) 和均方根误差 (RMSE)
from sklearn.metrics import mean_squared_error, mean_absolute_error,r2_score,explained_variance_score


# 计算NRMSE
def normalized_root_mean_squared_error(y_true, y_pred):
    mse = mean_squared_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    range_y = np.max(y_true) - np.min(y_true)
    return rmse / range_y

mse = mean_squared_error(y_test_original, y_pred_original)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test_original, y_pred_original)
# 计算 MBE
mbe = np.mean(y_test_original - y_pred_original)
nrmse = normalized_root_mean_squared_error(y_test_original, y_pred_original)
r2 = r2_score(y_test_original, y_pred_original)
evs = explained_variance_score(y_test_original, y_pred_original)
print("Mean Squared Error (MSE):", mse)
print("Root Mean Squared Error (RMSE):", rmse)
print("Mean Absolute Error (MAE):", mae)
print("Mean Bias Error(MBE):",mbe)
print("NRMSE:", nrmse)
print("Explained Variance Score (EVS):", evs)
print("R² Score:", r2)
# Out:
# Mean Squared Error (MSE): 46.01009575414133
# Root Mean Squared Error (RMSE): 6.783074211162763
# Mean Absolute Error (MAE): 3.848088967556624
# Mean Bias Error(MBE): 1.1781194248058096
# NRMSE: 0.03363212499860927
# Explained Variance Score (EVS): 0.9783590251928592
# R² Score: 0.9776858855746936

# %%
"""
Mean Squared Error (MSE): 46.01009575414133
Root Mean Squared Error (RMSE): 6.783074211162763
Mean Absolute Error (MAE): 3.848088967556624
Mean Bias Error(MBE): 1.1781194248058096
NRMSE: 0.03363212499860927
Explained Variance Score (EVS): 0.9783590251928592
R² Score: 0.9776858855746936
"""
