# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('wind2019.csv')
df.head(100)
# Out:
#                      时间  测风塔10m风速(m/s)  测风塔30m风速(m/s)  测风塔50m风速(m/s)  \
# 0   2019-01-01 00:00:00          0.223          0.000          0.000
# 1   2019-01-01 00:15:00          0.000          0.000          0.000
# 2   2019-01-01 00:30:00          0.000          0.000          0.000
# 3   2019-01-01 00:45:00          0.818          0.000          0.000
# 4   2019-01-01 01:00:00          1.041          0.000          0.297
# ..                  ...            ...            ...            ...
# 95  2019-01-01 23:45:00          3.155          3.461          2.798
# 96  2019-01-02 00:00:00          2.543          2.798          2.033
# 97  2019-01-02 00:15:00          1.829          2.747          2.135
# 98  2019-01-02 00:30:00          2.645          2.033          2.390
# 99  2019-01-02 00:45:00          3.308          2.135          2.849
#
#     测风塔10m风向(°)  测风塔30m风向(°)  测风塔50m风向(°)   温度(°)  气压(hPa)   湿度(%)  实际发电功率（mw）
# 0       166.816      177.355        6.224 -13.154  898.710  53.497    0.979591
# 1       166.832      177.356        6.526 -13.864  898.621  55.999    1.150984
# 2       166.859      177.353       28.936 -14.461  898.497  57.747    1.066162
# 3       166.894      177.344       29.212 -13.066  898.329  54.162    0.923717
# 4       166.892      177.352       29.378 -12.823  898.356  52.807    0.813552
# ..          ...          ...          ...     ...      ...     ...         ...
# 95      169.334      161.863        6.641 -11.289  892.893  51.098    0.954867
# 96      169.808      167.790        6.497 -11.851  892.889  52.669    1.301044
# 97      183.806      178.947        6.696 -11.293  892.827  51.019    1.229518
# 98      160.364      186.116        6.881 -12.165  892.663  53.786    1.001882
# 99      157.742      187.094        6.902 -13.097  892.566  57.127    0.953660
#
# [100 rows x 11 columns]

# %%
idx_df = df.set_index(['时间'])
idx_df.describe().T  #用于计算数值列的描述性统计信息，如计数、均值、标准差、最小值、最大值等
# Out:
#                  count        mean        std        min        25%  \
# 测风塔10m风速(m/s)  35040.0    4.818662   3.516523    0.00000    2.36400
# 测风塔30m风速(m/s)  35040.0    5.347264   3.836181    0.00000    2.62000
# 测风塔50m风速(m/s)  35040.0    5.773827   4.053695    0.00000    2.77200
# 测风塔10m风向(°)    35040.0  156.220382  86.821714    0.00000   82.25375
# 测风塔30m风向(°)    35040.0  158.638939  89.835426    0.00000   79.70725
# 测风塔50m风向(°)    35040.0   11.587642  16.812424    0.00000    5.85200
# 温度(°)          35040.0   11.324763  14.027540  -18.66200   -1.57650
# 气压(hPa)        35040.0  888.509122   5.793348  874.58400  883.63200
# 湿度(%)          35040.0   33.592505  20.761404    2.50600   16.64700
# 实际发电功率（mw）     35040.0   53.907954  56.733980    0.25836    3.52621
#
#                       50%        75%        max
# 测风塔10m风速(m/s)    3.869000    6.60200   19.24600
# 测风塔30m风速(m/s)    4.481000    7.31200   21.05600
# 测风塔50m风速(m/s)    4.660000    8.00000   22.38200
# 测风塔10m风向(°)    137.966500  230.50950  359.94600
# 测风塔30m风向(°)    137.621000  239.89550  360.00000
# 测风塔50m风向(°)      6.392000   11.53925  355.82300
# 温度(°)           13.105500   23.04225   40.13100
# 气压(hPa)        888.638000  892.70800  905.30700
# 湿度(%)           28.122000   47.54425   94.92100
# 实际发电功率（mw）      29.037047   99.74149  202.22884

# %%
idx_df.head(10)
# Out:
#                      测风塔10m风速(m/s)  测风塔30m风速(m/s)  测风塔50m风速(m/s)  测风塔10m风向(°)  \
# 时间
# 2019-01-01 00:00:00          0.223          0.000          0.000      166.816
# 2019-01-01 00:15:00          0.000          0.000          0.000      166.832
# 2019-01-01 00:30:00          0.000          0.000          0.000      166.859
# 2019-01-01 00:45:00          0.818          0.000          0.000      166.894
# 2019-01-01 01:00:00          1.041          0.000          0.297      166.892
# 2019-01-01 01:15:00          1.676          0.520          1.319      166.916
# 2019-01-01 01:30:00          2.645          1.472          2.033      166.872
# 2019-01-01 01:45:00          1.880          2.747          2.339      176.703
# 2019-01-01 02:00:00          1.676          2.543          2.543      176.739
# 2019-01-01 02:15:00          0.000          0.149          2.798      176.704
#
#                      测风塔30m风向(°)  测风塔50m风向(°)   温度(°)  气压(hPa)   湿度(%)  \
# 时间
# 2019-01-01 00:00:00      177.355        6.224 -13.154  898.710  53.497
# 2019-01-01 00:15:00      177.356        6.526 -13.864  898.621  55.999
# 2019-01-01 00:30:00      177.353       28.936 -14.461  898.497  57.747
# 2019-01-01 00:45:00      177.344       29.212 -13.066  898.329  54.162
# 2019-01-01 01:00:00      177.352       29.378 -12.823  898.356  52.807
# 2019-01-01 01:15:00      177.356       12.255 -12.793  898.196  51.031
# 2019-01-01 01:30:00      177.280        6.489 -13.671  898.076  53.597
# 2019-01-01 01:45:00      192.212        8.162 -13.905  897.939  54.602
# 2019-01-01 02:00:00      206.758        9.875 -13.270  897.775  53.981
# 2019-01-01 02:15:00      206.675        9.206 -13.598  897.779  54.478
#
#                      实际发电功率（mw）
# 时间
# 2019-01-01 00:00:00    0.979591
# 2019-01-01 00:15:00    1.150984
# 2019-01-01 00:30:00    1.066162
# 2019-01-01 00:45:00    0.923717
# 2019-01-01 01:00:00    0.813552
# 2019-01-01 01:15:00    1.385237
# 2019-01-01 01:30:00    5.187509
# 2019-01-01 01:45:00    8.714045
# 2019-01-01 02:00:00   11.367244
# 2019-01-01 02:15:00   11.250483

# %%
idx_df.isnull().sum()#DataFrame 中每列的缺失值数量。通过这个操作，您可以了解每列中缺失值的分布情况，并进行进一步的数据清洗或处理。
# Out:
# 测风塔10m风速(m/s)    0
# 测风塔30m风速(m/s)    0
# 测风塔50m风速(m/s)    0
# 测风塔10m风向(°)      0
# 测风塔30m风向(°)      0
# 测风塔50m风向(°)      0
# 温度(°)            0
# 气压(hPa)          0
# 湿度(%)            0
# 实际发电功率（mw）       0
# dtype: int64

# %%
import matplotlib.font_manager as font_manager

# 指定中文字体文件路径
font_path = 'C:/Windows/Fonts/simsun.ttc'

# 加载中文字体
prop = font_manager.FontProperties(fname=font_path)

# 设置中文字体为默认字体
plt.rcParams['font.family'] = prop.get_name()
fig,ax = plt.subplots(figsize = (10,10))
sns.heatmap(idx_df.corr(),ax=ax,annot = True)
# Out:
# D:\JetBrains\ANACONDA\envs\py37\lib\site-packages\seaborn\utils.py:80: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.draw()
# <AxesSubplot:>
# D:\JetBrains\ANACONDA\envs\py37\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   func(*args, **kwargs)
# D:\JetBrains\ANACONDA\envs\py37\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
idx_df.corr()['实际发电功率（mw）'].sort_values(ascending=False)
# Out:
# 实际发电功率（mw）       1.000000
# 测风塔50m风速(m/s)    0.784718
# 测风塔30m风速(m/s)    0.761795
# 测风塔10m风速(m/s)    0.746070
# 温度(°)            0.132965
# 气压(hPa)         -0.127836
# 湿度(%)           -0.136031
# 测风塔50m风向(°)     -0.190069
# 测风塔10m风向(°)     -0.344054
# 测风塔30m风向(°)     -0.369254
# Name: 实际发电功率（mw）, dtype: float64

# %%
idx_df.shape
# Out:
# (35040, 10)

# %%
df2 = idx_df.drop(['测风塔30m风向(°)','测风塔10m风向(°)'],axis=1)

df2.shape
df2.head(100)
# Out:
#                      测风塔10m风速(m/s)  测风塔30m风速(m/s)  测风塔50m风速(m/s)  测风塔50m风向(°)  \
# 时间
# 2019-01-01 00:00:00          0.223          0.000          0.000        6.224
# 2019-01-01 00:15:00          0.000          0.000          0.000        6.526
# 2019-01-01 00:30:00          0.000          0.000          0.000       28.936
# 2019-01-01 00:45:00          0.818          0.000          0.000       29.212
# 2019-01-01 01:00:00          1.041          0.000          0.297       29.378
# ...                            ...            ...            ...          ...
# 2019-01-01 23:45:00          3.155          3.461          2.798        6.641
# 2019-01-02 00:00:00          2.543          2.798          2.033        6.497
# 2019-01-02 00:15:00          1.829          2.747          2.135        6.696
# 2019-01-02 00:30:00          2.645          2.033          2.390        6.881
# 2019-01-02 00:45:00          3.308          2.135          2.849        6.902
#
#                       温度(°)  气压(hPa)   湿度(%)  实际发电功率（mw）
# 时间
# 2019-01-01 00:00:00 -13.154  898.710  53.497    0.979591
# 2019-01-01 00:15:00 -13.864  898.621  55.999    1.150984
# 2019-01-01 00:30:00 -14.461  898.497  57.747    1.066162
# 2019-01-01 00:45:00 -13.066  898.329  54.162    0.923717
# 2019-01-01 01:00:00 -12.823  898.356  52.807    0.813552
# ...                     ...      ...     ...         ...
# 2019-01-01 23:45:00 -11.289  892.893  51.098    0.954867
# 2019-01-02 00:00:00 -11.851  892.889  52.669    1.301044
# 2019-01-02 00:15:00 -11.293  892.827  51.019    1.229518
# 2019-01-02 00:30:00 -12.165  892.663  53.786    1.001882
# 2019-01-02 00:45:00 -13.097  892.566  57.127    0.953660
#
# [100 rows x 8 columns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 35040 entries, 2019-01-01 00:00:00 to 2019-12-31 23:45:00
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   测风塔10m风速(m/s)  35040 non-null  float64
#  1   测风塔30m风速(m/s)  35040 non-null  float64
#  2   测风塔50m风速(m/s)  35040 non-null  float64
#  3   测风塔50m风向(°)    35040 non-null  float64
#  4   温度(°)          35040 non-null  float64
#  5   气压(hPa)        35040 non-null  float64
#  6   湿度(%)          35040 non-null  float64
#  7   实际发电功率（mw）     35040 non-null  float64
# dtypes: float64(8)
# memory usage: 2.4+ MB

# %%
x = df2.iloc[:,:].values #转化成numpy类型
print(x)
print(x.shape)
# Out:
# [[2.23000000e-01 0.00000000e+00 0.00000000e+00 ... 8.98710000e+02
#   5.34970000e+01 9.79591000e-01]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 8.98621000e+02
#   5.59990000e+01 1.15098400e+00]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 8.98497000e+02
#   5.77470000e+01 1.06616200e+00]
#  ...
#  [7.46400000e+00 8.15300000e+00 8.76500000e+00 ... 8.88383000e+02
#   4.11360000e+01 1.34717210e+02]
#  [5.70500000e+00 7.15800000e+00 8.07600000e+00 ... 8.88389000e+02
#   4.12880000e+01 1.26557410e+02]
#  [7.15800000e+00 8.00000000e+00 9.68300000e+00 ... 8.88469000e+02
#   4.01230000e+01 1.09673615e+02]]
# (35040, 8)

# %%
from sklearn.preprocessing import MinMaxScaler
x_sc = MinMaxScaler()
x = x_sc.fit_transform(x)
# print(x.shape)
# print(x)

# 获取归一化时用的最大值和最小值
max_values = x_sc.data_max_
min_values = x_sc.data_min_

# 打印每个特征的最大值和最小值
for feature, max_val, min_val in zip(range(len(max_values)), max_values, min_values):
    print(f"Feature {feature}: Max Value = {max_val}, Min Value = {min_val}")
# Out:
# Feature 0: Max Value = 19.246, Min Value = 0.0
# Feature 1: Max Value = 21.055999999999997, Min Value = 0.0
# Feature 2: Max Value = 22.381999999999998, Min Value = 0.0
# Feature 3: Max Value = 355.82300000000004, Min Value = 0.0
# Feature 4: Max Value = 40.131, Min Value = -18.662
# Feature 5: Max Value = 905.307, Min Value = 874.584
# Feature 6: Max Value = 94.921, Min Value = 2.506
# Feature 7: Max Value = 202.22884, Min Value = 0.25836

# %%
# 滑动窗口截取数据

def multivariate_data(dataset, target, start_index, end_index, history_size,
                      target_size, step, single_step=False):
    data = []
    labels = []

    start_index = start_index + history_size
    
    if end_index is None:
        end_index = len(dataset) - target_size

    for i in range(start_index, end_index):
        indices = range(i-history_size, i, step) # step表示滑动步长
        data.append(dataset[indices])

        if single_step:
            labels.append(target[i+target_size])
        else:
            labels.append(target[i:i+target_size])

    return np.array(data), np.array(labels)

# %%
past_history = 8  #2小时观测值
future_target = 0  #下一个时间点的
STEP = 1

x_train_single, y_train_single = multivariate_data(x, x[:, -1], 0,
                                                   24528, past_history,
                                                   future_target, STEP,
                                                   single_step=True)
x_val_single, y_val_single = multivariate_data(x, x[:, -1],
                                              24528 , 31536, past_history,
                                               future_target, STEP,
                                               single_step=True)
x_test_single, y_test_single = multivariate_data(x, x[:, -1],
                                               31536, None, past_history,
                                               future_target, STEP,
                                               single_step=True)
print(x_train_single.shape)
print(y_train_single)
print(x_val_single.shape)
print(x_test_single.shape)
print(x_train_single)
print(y_test_single.shape)
# Out:
# (24520, 8, 8)
# [0.05500251 0.0544244  0.04823228 ... 0.0103412  0.0256572  0.02965432]
# (7000, 8, 8)
# (3496, 8, 8)
# [[[0.01158682 0.         0.         ... 0.78527488 0.55176108 0.00357097]
#   [0.         0.         0.         ... 0.78237802 0.5788346  0.00441958]
#   [0.         0.         0.         ... 0.77834196 0.59774928 0.0039996 ]
#   ...
#   [0.08708303 0.02469605 0.05893128 ... 0.76854474 0.5250771  0.00557941]
#   [0.13743115 0.06990881 0.09083192 ... 0.76463887 0.55284315 0.02440529]
#   [0.09768264 0.13046163 0.10450362 ... 0.76017967 0.56371801 0.04186594]]
#
#  [[0.         0.         0.         ... 0.78237802 0.5788346  0.00441958]
#   [0.         0.         0.         ... 0.77834196 0.59774928 0.0039996 ]
#   [0.04250234 0.         0.         ... 0.77287374 0.55895688 0.00329433]
#   ...
#   [0.13743115 0.06990881 0.09083192 ... 0.76463887 0.55284315 0.02440529]
#   [0.09768264 0.13046163 0.10450362 ... 0.76017967 0.56371801 0.04186594]
#   [0.08708303 0.12077318 0.11361809 ... 0.75484165 0.55699832 0.05500251]]
#
#  [[0.         0.         0.         ... 0.77834196 0.59774928 0.0039996 ]
#   [0.04250234 0.         0.         ... 0.77287374 0.55895688 0.00329433]
#   [0.05408916 0.         0.01326959 ... 0.77375256 0.54429476 0.00274888]
#   ...
#   [0.09768264 0.13046163 0.10450362 ... 0.76017967 0.56371801 0.04186594]
#   [0.08708303 0.12077318 0.11361809 ... 0.75484165 0.55699832 0.05500251]
#   [0.         0.00707637 0.12501117 ... 0.75497185 0.56237624 0.0544244 ]]
#
#  ...
#
#  [[0.11623194 0.10139628 0.08171745 ... 0.67112587 0.60132013 0.00116977]
#   [0.08178323 0.06022036 0.03985345 ... 0.67356703 0.51809771 0.00098085]
#   [0.10298244 0.09897416 0.09083192 ... 0.67662663 0.43118541 0.00094307]
#   ...
#   [0.0272784  0.0331022  0.0466893  ... 0.68020701 0.30754748 0.00098745]
#   [0.06609166 0.06174012 0.07260298 ... 0.68036976 0.32674349 0.00094245]
#   [0.12948145 0.12319529 0.12728979 ... 0.68440582 0.31284965 0.00207865]]
#
#  [[0.08178323 0.06022036 0.03985345 ... 0.67356703 0.51809771 0.00098085]
#   [0.10298244 0.09897416 0.09083192 ... 0.67662663 0.43118541 0.00094307]
#   [0.08708303 0.09412994 0.0885533  ... 0.6776031  0.370178   0.00090655]
#   ...
#   [0.06609166 0.06174012 0.07260298 ... 0.68036976 0.32674349 0.00094245]
#   [0.12948145 0.12319529 0.12728979 ... 0.68440582 0.31284965 0.00207865]
#   [0.1309363  0.14015008 0.13640425 ... 0.67962113 0.27960829 0.0103412 ]]
#
#  [[0.10298244 0.09897416 0.09083192 ... 0.67662663 0.43118541 0.00094307]
#   [0.08708303 0.09412994 0.0885533  ... 0.6776031  0.370178   0.00090655]
#   [0.01932869 0.01894947 0.04128317 ... 0.68092309 0.34102689 0.0009037 ]
#   ...
#   [0.12948145 0.12319529 0.12728979 ... 0.68440582 0.31284965 0.00207865]
#   [0.1309363  0.14015008 0.13640425 ... 0.67962113 0.27960829 0.0103412 ]
#   [0.17717967 0.14741641 0.14096149 ... 0.67402272 0.26369096 0.0256572 ]]]
# (3496,)

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import LSTM,Bidirectional,GRU,Input, Conv1D,Multiply,Flatten,MaxPooling1D
from tensorflow.keras.layers import Dense, Activation, BatchNormalization, Dropout,Permute,Lambda,RepeatVector
from tensorflow.keras import regularizers
from tensorflow.keras.optimizers import RMSprop, Adam, SGD
import datetime
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow.keras.backend as K
#from keras_self_attention import SeqSelfAttention
from tensorflow.keras.models import Model
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.callbacks import ReduceLROnPlateau

# %%
def CNN():
    visible1 = Input(shape=(8, 8))
    cnn1 = Conv1D(filters=8, kernel_size=1, activation='relu', padding='same')(visible1)
    cnn1 = MaxPooling1D(pool_size=2)(cnn1)
    cnn2 = Conv1D(filters=16, kernel_size=3, activation='relu')(cnn1)
    cnn2 = MaxPooling1D(pool_size=2)(cnn2)
    cnn = Flatten()(cnn2)

    
    dense = Dense(units=64, activation='relu')(cnn)
    output = Dense(units=1, activation='relu')(dense)
    
    model = Model(inputs=visible1, outputs=output)
    adam = Adam(learning_rate=0.001)
    
    return model

# %%
m = CNN()
m.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 8, 8)]            0
# _________________________________________________________________
# conv1d (Conv1D)              (None, 8, 8)              72
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 4, 8)              0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 2, 16)             400
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 1, 16)             0
# _________________________________________________________________
# flatten (Flatten)            (None, 16)                0
# _________________________________________________________________
# dense (Dense)                (None, 64)                1088
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 1,625
# Trainable params: 1,625
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 编译模型
m.compile(optimizer='adam', loss='mse', metrics=[tf.keras.metrics.RootMeanSquaredError()])

# 训练模型
# 训练模型
hist = m.fit(x_train_single, y_train_single, epochs=100, batch_size=32,validation_data=(x_val_single, y_val_single), verbose=1)
# Out:
# Epoch 1/100
# 767/767 [==============================] - 4s 5ms/step - loss: 0.0208 - root_mean_squared_error: 0.1366 - val_loss: 0.0051 - val_root_mean_squared_error: 0.0712
# Epoch 2/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.0054 - root_mean_squared_error: 0.0733 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0613
# Epoch 3/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.0045 - root_mean_squared_error: 0.0668 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0547
# Epoch 4/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.0042 - root_mean_squared_error: 0.0648 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0559
# Epoch 5/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.0041 - root_mean_squared_error: 0.0642 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0546
# Epoch 6/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.0039 - root_mean_squared_error: 0.0621 - val_loss: 0.0029 - val_root_mean_squared_error: 0.0539
# Epoch 7/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.0036 - root_mean_squared_error: 0.0604 - val_loss: 0.0027 - val_root_mean_squared_error: 0.0515
# Epoch 8/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.0037 - root_mean_squared_error: 0.0607 - val_loss: 0.0027 - val_root_mean_squared_error: 0.0521
# Epoch 9/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.0036 - root_mean_squared_error: 0.0596 - val_loss: 0.0025 - val_root_mean_squared_error: 0.0497
# Epoch 10/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.0035 - root_mean_squared_error: 0.0595 - val_loss: 0.0023 - val_root_mean_squared_error: 0.0483
# Epoch 11/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.0033 - root_mean_squared_error: 0.0576 - val_loss: 0.0026 - val_root_mean_squared_error: 0.0512
# Epoch 12/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.0032 - root_mean_squared_error: 0.0569 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0648
# Epoch 13/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.0035 - root_mean_squared_error: 0.0590 - val_loss: 0.0022 - val_root_mean_squared_error: 0.0468
# Epoch 14/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.0033 - root_mean_squared_error: 0.0571 - val_loss: 0.0023 - val_root_mean_squared_error: 0.0480
# Epoch 15/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.0033 - root_mean_squared_error: 0.0570 - val_loss: 0.0022 - val_root_mean_squared_error: 0.0471
# Epoch 16/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.0032 - root_mean_squared_error: 0.0563 - val_loss: 0.0023 - val_root_mean_squared_error: 0.0477
# Epoch 17/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.0031 - root_mean_squared_error: 0.0553 - val_loss: 0.0022 - val_root_mean_squared_error: 0.0464
# Epoch 18/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.0031 - root_mean_squared_error: 0.0558 - val_loss: 0.0023 - val_root_mean_squared_error: 0.0478
# Epoch 19/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.0032 - root_mean_squared_error: 0.0563 - val_loss: 0.0022 - val_root_mean_squared_error: 0.0473
# Epoch 20/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.0031 - root_mean_squared_error: 0.0559 - val_loss: 0.0021 - val_root_mean_squared_error: 0.0454
# Epoch 21/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.0031 - root_mean_squared_error: 0.0560 - val_loss: 0.0027 - val_root_mean_squared_error: 0.0516
# Epoch 22/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.0029 - root_mean_squared_error: 0.0542 - val_loss: 0.0021 - val_root_mean_squared_error: 0.0461
# Epoch 23/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.0028 - root_mean_squared_error: 0.0529 - val_loss: 0.0024 - val_root_mean_squared_error: 0.0493
# Epoch 24/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.0030 - root_mean_squared_error: 0.0552 - val_loss: 0.0026 - val_root_mean_squared_error: 0.0513
# Epoch 25/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.0031 - root_mean_squared_error: 0.0553 - val_loss: 0.0021 - val_root_mean_squared_error: 0.0462
# Epoch 26/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.0028 - root_mean_squared_error: 0.0532 - val_loss: 0.0020 - val_root_mean_squared_error: 0.0445
# Epoch 27/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.0029 - root_mean_squared_error: 0.0543 - val_loss: 0.0020 - val_root_mean_squared_error: 0.0447
# Epoch 28/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.0029 - root_mean_squared_error: 0.0537 - val_loss: 0.0020 - val_root_mean_squared_error: 0.0451
# Epoch 29/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.0030 - root_mean_squared_error: 0.0544 - val_loss: 0.0020 - val_root_mean_squared_error: 0.0442
# Epoch 30/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.0029 - root_mean_squared_error: 0.0538 - val_loss: 0.0021 - val_root_mean_squared_error: 0.0454
# Epoch 31/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.0029 - root_mean_squared_error: 0.0539 - val_loss: 0.0020 - val_root_mean_squared_error: 0.0444
# Epoch 32/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.0029 - root_mean_squared_error: 0.0540 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0435
# Epoch 33/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.0029 - root_mean_squared_error: 0.0536 - val_loss: 0.0023 - val_root_mean_squared_error: 0.0477
# Epoch 34/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.0031 - root_mean_squared_error: 0.0553 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0439
# Epoch 35/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.0028 - root_mean_squared_error: 0.0531 - val_loss: 0.0022 - val_root_mean_squared_error: 0.0472
# Epoch 36/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.0029 - root_mean_squared_error: 0.0537 - val_loss: 0.0027 - val_root_mean_squared_error: 0.0516
# Epoch 37/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.0030 - root_mean_squared_error: 0.0545 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0439
# Epoch 38/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.0027 - root_mean_squared_error: 0.0523 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0434
# Epoch 39/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.0028 - root_mean_squared_error: 0.0529 - val_loss: 0.0021 - val_root_mean_squared_error: 0.0454
# Epoch 40/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.0028 - root_mean_squared_error: 0.0531 - val_loss: 0.0022 - val_root_mean_squared_error: 0.0470
# Epoch 41/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.0029 - root_mean_squared_error: 0.0534 - val_loss: 0.0020 - val_root_mean_squared_error: 0.0444
# Epoch 42/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.0029 - root_mean_squared_error: 0.0537 - val_loss: 0.0020 - val_root_mean_squared_error: 0.0451
# Epoch 43/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.0026 - root_mean_squared_error: 0.0511 - val_loss: 0.0025 - val_root_mean_squared_error: 0.0499
# Epoch 44/100
# 767/767 [==============================] - 1s 2ms/step - loss: 0.0028 - root_mean_squared_error: 0.0528 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0433
# Epoch 45/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.0027 - root_mean_squared_error: 0.0523 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0432
# Epoch 46/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.0026 - root_mean_squared_error: 0.0515 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0441
# Epoch 47/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.0027 - root_mean_squared_error: 0.0522 - val_loss: 0.0022 - val_root_mean_squared_error: 0.0467
# Epoch 48/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.0027 - root_mean_squared_error: 0.0521 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0435
# Epoch 49/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.0028 - root_mean_squared_error: 0.0532 - val_loss: 0.0020 - val_root_mean_squared_error: 0.0448
# Epoch 50/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.0027 - root_mean_squared_error: 0.0519 - val_loss: 0.0020 - val_root_mean_squared_error: 0.0448
# Epoch 51/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.0027 - root_mean_squared_error: 0.0517 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0440
# Epoch 52/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.0029 - root_mean_squared_error: 0.0539 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0441
# Epoch 53/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.0026 - root_mean_squared_error: 0.0515 - val_loss: 0.0020 - val_root_mean_squared_error: 0.0447
# Epoch 54/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.0028 - root_mean_squared_error: 0.0526 - val_loss: 0.0018 - val_root_mean_squared_error: 0.0426
# Epoch 55/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.0028 - root_mean_squared_error: 0.0526 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0432
# Epoch 56/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.0027 - root_mean_squared_error: 0.0524 - val_loss: 0.0020 - val_root_mean_squared_error: 0.0444
# Epoch 57/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.0026 - root_mean_squared_error: 0.0514 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0437
# Epoch 58/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.0027 - root_mean_squared_error: 0.0516 - val_loss: 0.0018 - val_root_mean_squared_error: 0.0428
# Epoch 59/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.0027 - root_mean_squared_error: 0.0522 - val_loss: 0.0021 - val_root_mean_squared_error: 0.0453
# Epoch 60/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.0026 - root_mean_squared_error: 0.0507 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0441
# Epoch 61/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.0027 - root_mean_squared_error: 0.0519 - val_loss: 0.0018 - val_root_mean_squared_error: 0.0427
# Epoch 62/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.0028 - root_mean_squared_error: 0.0532 - val_loss: 0.0020 - val_root_mean_squared_error: 0.0445
# Epoch 63/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.0027 - root_mean_squared_error: 0.0515 - val_loss: 0.0020 - val_root_mean_squared_error: 0.0447
# Epoch 64/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.0027 - root_mean_squared_error: 0.0523 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0433
# Epoch 65/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.0027 - root_mean_squared_error: 0.0516 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0440
# Epoch 66/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.0026 - root_mean_squared_error: 0.0514 - val_loss: 0.0021 - val_root_mean_squared_error: 0.0461
# Epoch 67/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.0027 - root_mean_squared_error: 0.0518 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0437
# Epoch 68/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.0026 - root_mean_squared_error: 0.0510 - val_loss: 0.0020 - val_root_mean_squared_error: 0.0448
# Epoch 69/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.0027 - root_mean_squared_error: 0.0520 - val_loss: 0.0025 - val_root_mean_squared_error: 0.0497
# Epoch 70/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.0026 - root_mean_squared_error: 0.0505 - val_loss: 0.0018 - val_root_mean_squared_error: 0.0424
# Epoch 71/100
# 767/767 [==============================] - 1s 2ms/step - loss: 0.0027 - root_mean_squared_error: 0.0516 - val_loss: 0.0021 - val_root_mean_squared_error: 0.0457
# Epoch 72/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.0026 - root_mean_squared_error: 0.0507 - val_loss: 0.0018 - val_root_mean_squared_error: 0.0428
# Epoch 73/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.0027 - root_mean_squared_error: 0.0523 - val_loss: 0.0018 - val_root_mean_squared_error: 0.0426
# Epoch 74/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.0027 - root_mean_squared_error: 0.0515 - val_loss: 0.0021 - val_root_mean_squared_error: 0.0461
# Epoch 75/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.0026 - root_mean_squared_error: 0.0514 - val_loss: 0.0020 - val_root_mean_squared_error: 0.0444
# Epoch 76/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.0026 - root_mean_squared_error: 0.0513 - val_loss: 0.0020 - val_root_mean_squared_error: 0.0445
# Epoch 77/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.0027 - root_mean_squared_error: 0.0518 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0435
# Epoch 78/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.0026 - root_mean_squared_error: 0.0509 - val_loss: 0.0018 - val_root_mean_squared_error: 0.0425
# Epoch 79/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.0027 - root_mean_squared_error: 0.0518 - val_loss: 0.0020 - val_root_mean_squared_error: 0.0442
# Epoch 80/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.0027 - root_mean_squared_error: 0.0517 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0439
# Epoch 81/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.0026 - root_mean_squared_error: 0.0510 - val_loss: 0.0018 - val_root_mean_squared_error: 0.0423
# Epoch 82/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.0027 - root_mean_squared_error: 0.0518 - val_loss: 0.0020 - val_root_mean_squared_error: 0.0450
# Epoch 83/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.0027 - root_mean_squared_error: 0.0517 - val_loss: 0.0018 - val_root_mean_squared_error: 0.0427
# Epoch 84/100
# 767/767 [==============================] - 1s 990us/step - loss: 0.0026 - root_mean_squared_error: 0.0507 - val_loss: 0.0020 - val_root_mean_squared_error: 0.0443
# Epoch 85/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.0027 - root_mean_squared_error: 0.0517 - val_loss: 0.0018 - val_root_mean_squared_error: 0.0421
# Epoch 86/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.0026 - root_mean_squared_error: 0.0513 - val_loss: 0.0021 - val_root_mean_squared_error: 0.0460
# Epoch 87/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.0026 - root_mean_squared_error: 0.0513 - val_loss: 0.0018 - val_root_mean_squared_error: 0.0426
# Epoch 88/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.0026 - root_mean_squared_error: 0.0514 - val_loss: 0.0021 - val_root_mean_squared_error: 0.0453
# Epoch 89/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.0027 - root_mean_squared_error: 0.0518 - val_loss: 0.0018 - val_root_mean_squared_error: 0.0420
# Epoch 90/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.0026 - root_mean_squared_error: 0.0511 - val_loss: 0.0024 - val_root_mean_squared_error: 0.0494
# Epoch 91/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.0026 - root_mean_squared_error: 0.0511 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0434
# Epoch 92/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.0027 - root_mean_squared_error: 0.0521 - val_loss: 0.0020 - val_root_mean_squared_error: 0.0453
# Epoch 93/100
# 767/767 [==============================] - 1s 980us/step - loss: 0.0026 - root_mean_squared_error: 0.0510 - val_loss: 0.0018 - val_root_mean_squared_error: 0.0428
# Epoch 94/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.0026 - root_mean_squared_error: 0.0510 - val_loss: 0.0027 - val_root_mean_squared_error: 0.0517
# Epoch 95/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.0025 - root_mean_squared_error: 0.0503 - val_loss: 0.0025 - val_root_mean_squared_error: 0.0500
# Epoch 96/100
# 767/767 [==============================] - 1s 1ms/step - loss: 0.0026 - root_mean_squared_error: 0.0514 - val_loss: 0.0018 - val_root_mean_squared_error: 0.0426
# Epoch 97/100
# 767/767 [==============================] - 1s 990us/step - loss: 0.0027 - root_mean_squared_error: 0.0517 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0435
# Epoch 98/100
# 767/767 [==============================] - 1s 993us/step - loss: 0.0026 - root_mean_squared_error: 0.0508 - val_loss: 0.0020 - val_root_mean_squared_error: 0.0453
# Epoch 99/100
# 767/767 [==============================] - 1s 981us/step - loss: 0.0026 - root_mean_squared_error: 0.0509 - val_loss: 0.0018 - val_root_mean_squared_error: 0.0420
# Epoch 100/100
# 767/767 [==============================] - 1s 995us/step - loss: 0.0026 - root_mean_squared_error: 0.0506 - val_loss: 0.0021 - val_root_mean_squared_error: 0.0464

# %%
# 绘制损失函数曲线
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'val'], loc='upper right')
plt.show()

# %%
y_pred = m.predict(x_test_single)

# %%
print(y_pred)

max_target =202.22884  # 原始数据中的最大值
min_target =0.25836  # 原始数据中的最小值

y_pred_unnormalized = y_pred * (max_target - min_target) + min_target

y_test_single_unnormalized = y_test_single * (max_target - min_target) + min_target



y_pred_original = y_pred_unnormalized
y_test_original = y_test_single_unnormalized

print(y_pred_original)
# Out:
# [[0.2942304 ]
#  [0.18408453]
#  [0.08700735]
#  ...
#  [0.6095074 ]
#  [0.6282297 ]
#  [0.6455479 ]]
# [[ 59.684216]
#  [ 37.438004]
#  [ 17.831276]
#  ...
#  [123.360855]
#  [127.142204]
#  [130.63998 ]]

# %%
# 计算均方误差 (MSE) 和均方根误差 (RMSE)
from sklearn.metrics import mean_squared_error, mean_absolute_error,r2_score,explained_variance_score


# 计算NRMSE
def normalized_root_mean_squared_error(y_true, y_pred):
    mse = mean_squared_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    range_y = np.max(y_true) - np.min(y_true)
    return rmse / range_y

mse = mean_squared_error(y_test_original, y_pred_original)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test_original, y_pred_original)
# 计算 MBE
mbe = np.mean(y_test_original - y_pred_original)
nrmse = normalized_root_mean_squared_error(y_test_original, y_pred_original)
r2 = r2_score(y_test_original, y_pred_original)
evs = explained_variance_score(y_test_original, y_pred_original)
print("Mean Squared Error (MSE):", mse)
print("Root Mean Squared Error (RMSE):", rmse)
print("Mean Absolute Error (MAE):", mae)
print("Mean Bias Error(MBE):",mbe)
print("NRMSE:", nrmse)
print("Explained Variance Score (EVS):", evs)
print("R² Score:", r2)
# Out:
# Mean Squared Error (MSE): 85.49160249448563
# Root Mean Squared Error (RMSE): 9.24616690821043
# Mean Absolute Error (MAE): 5.418510596120381
# Mean Bias Error(MBE): 3.1595039979222563
# NRMSE: 0.04584473522391719
# Explained Variance Score (EVS): 0.9633793519629467
# R² Score: 0.958538025857226

# %%
"""
Mean Squared Error (MSE): 85.49160249448563
Root Mean Squared Error (RMSE): 9.24616690821043
Mean Absolute Error (MAE): 5.418510596120381
Mean Bias Error(MBE): 3.1595039979222563
NRMSE: 0.04584473522391719
Explained Variance Score (EVS): 0.9633793519629467
R² Score: 0.958538025857226
"""
